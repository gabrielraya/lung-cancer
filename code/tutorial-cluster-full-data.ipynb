# %% [markdown]
# # Neural Image Compression #
#
# Using local Data to test functionality with a few WSIs

# %% [markdown]
# ## Imports ##

# %%
# Import NIC to python path
import sys
nic_dir = '/mnt/netcache/pathology/projects/pathology-weakly-supervised-lung-cancer-growth-pattern-prediction/code/neural-image-compression-private'
sys.path.append(nic_dir +'/source')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
from tqdm import tqdm
import os, shutil
from os.path import join, dirname, exists
import keras
from gradcam_wsi import gradcam_on_dataset
from preprocessing import data_to_csv, create_csv, generate_csv_files

# %% [markdown]
# ## Data ##
#
# To demonstrate the functionality of NIC, we will need a set of whole-slide images (WSIs) with their respective slide-level labels. In this case, we will use the WSIs that can be found using the following pattern:
#
# These data was already reorganized, it is, all the tiff files are contained in one folder for each class.
#
# These are a small version of the TCGA dataset:
#
# `/mnt/netcache/pathology/projects/data/tcga_luad/images_diagnostic`
#
# `/mnt/netcache/pathology/projects/data/tcga_lusc/images_diagnostic`
#
# The data we are going to use is only the **diagnostic** data and no the **tissue** data. The mask are already given, but we will have to implementa script to create this masks that filter out the background.
#
#
# Because there is no slide-level csv file, we have to create one, this will be created after once we get the featurized wsi. FIle should be located at  from:
#
# `/mnt/netcache/pathology/projects/data/slide_original_list_tcga.csv`

# %%
# Creates csv from original data

# project and data directories
root_dir = r'/mnt/netcache/pathology/projects/pathology-weakly-supervised-lung-cancer-growth-pattern-prediction'
data_dir = r'/mnt/netcache/pathology/archives/lung'

# wsi directories
dir_luad_wsi = os.path.join(data_dir, 'TCGA_LUAD', 'wsi_diagnostic_tif')
dir_lusc_wsi = os.path.join(data_dir, 'TCGA_LUSC', 'wsi_diagnostic_tif')
dir_luad_wsi_mask = os.path.join(data_dir, 'TCGA_LUAD', 'tissue_masks_diagnostic')
dir_lusc_wsi_mask = os.path.join(data_dir, 'TCGA_LUSC', 'tissue_masks_diagnostic')

# compressed image directories
vectorized_luad_dir = join(root_dir, 'results', 'tcga_luad', 'vectorized')
vectorized_lusc_dir = join(root_dir, 'results', 'tcga_lusc', 'vectorized')
featurized_luad_dir = join(root_dir, 'results', 'tcga_luad', 'featurized', 'no_augmentations')
featurized_lusc_dir = join(root_dir, 'results', 'tcga_lusc', 'featurized', 'no_augmentations')

# results directory 
result_dir = join(root_dir, 'results', 'baseline_model_full_data')  # store the results from trained model
gradcam_dir = join(result_dir, 'gradcam')        # store gradcam results

# Set paths
model_path = './neural-image-compression-private/models/encoders_patches_pathology/encoder_bigan.h5'
csv_train = os.path.join(root_dir, 'data','train_slide_list_tcga.csv')
csv_val = os.path.join(root_dir, 'data','validation_slide_list_tcga.csv')
csv_test = os.path.join(root_dir, 'data','test_slide_list_tcga.csv')

# csv paths
csv_path_wsi =  os.path.join(root_dir,'data/slide_original_list_tcga.csv')
csv_path_compressed_wsi = os.path.join(root_dir, 'data', 'slide_compressed_list_tcga.csv')

cache_dir = '/home/user/'  # used to store local copies of files during I/O operations (useful in cluster

# %% [markdown]
# ## 0. Preprocessing
#
# We need to create a csv file with the file names and labels. Plus we need to create csv files with the split file names for trainig/testing and validation.
#
# This csv files must be fixed! So no changes can be made later, for this reason is a good idea to create a csv containing the partitions

# %%
# create main csv file 
print('Creating main csv data files from original data...')
create_csv(dir_luad_wsi, dir_lusc_wsi, csv_path_wsi, '.tif')

# read files to check shapes
df = pd.read_csv(csv_path_wsi)
print(f'Files were read with shapes: {df.shape}')
# Out:
# 100%|██████████| 531/531 [00:00<00:00, 181632.31it/s]
# 100%|██████████| 506/506 [00:00<00:00, 163531.96it/s]
# Creating main csv data files from original data...
# Csv file sucessfully exported!
# Files were read with shapes: (1037, 2)

# %%
np.random.seed(7)
# creat split csv file for training/valid/testing
featurized_dir = {'data_dir_luad': featurized_luad_dir, 'data_dir_lusc': featurized_lusc_dir}
csv_path = {'csv_train': csv_train, 'csv_val': csv_val, 'csv_test': csv_test}

# Create csv files 
print('Creating compressed wsi csv file ...')
create_csv(featurized_luad_dir, featurized_lusc_dir, csv_path_compressed_wsi)

print('Creating split train/validation/test csv files ...')
generate_csv_files(csv_path_compressed_wsi, csv_train, csv_val, csv_test, test_size=0.2, validation_size = 0.3)

# read files to check shapes
df_train = pd.read_csv(csv_train);  df_val = pd.read_csv(csv_val);   df_test = pd.read_csv(csv_test)
print(f'Files were read with shapes: Training: {df_train.shape}, Validation {df_val.shape}, Testing {df_test.shape}')
print(f'Total files: Files were read with shapes: {df_train.shape[0]+df_val.shape[0]+df_test.shape[0]}')
# Out:
# 100%|██████████| 1593/1593 [00:00<00:00, 409357.08it/s]
# Creating compressed wsi csv file ...
# 100%|██████████| 1518/1518 [00:00<00:00, 305501.34it/s]
# Csv file sucessfully exported!
# Creating split train/validation/test csv files ...
# Train/validation/test csv files sucessfully exported!
# Files were read with shapes: Training: (580, 2), Validation (249, 2), Testing (208, 2)
# Total files: Files were read with shapes: 1037

# %%
df_train['partition'] ='training'
df_val['partition'] ='validation'
df_test['partition'] ='testing'

# %%
pd.concat([df_train, df_val, df_test]).to_csv(join(root_dir,'data', 'data.csv'),index=False)

# %% [markdown]
# ## 1. Encoder network ##
#
# To perform NIC, we will need an encoder network to transform small image patches into embedding vectors. According to the paper, BiGAN produces the best unsupervised encoder and it is the one we will train here.
#
# Alternatively, a collection of pretrained encoders (the one used in the NIC paper) can be found in
#
# `./models/encoders_patches_pathology/*.h5`
#
# Remember that these pretrained encoders accept 128x128x3 patches taken at 0.5 um/px resolution (often level 1), except for the BiGAN model that takes 64x64x3 at 1 um/px (often level 2).

# %% [markdown]
# In order to train the BiGAN model, we will first extract patches from the slides in the `encoder` partition. We will sample 10K patches per slide, producing ~260K patches in total. We select 96x96 patches to perform crop augmentation during training later.

# %%
# # Dont run this we, will train later the encoder but not now. 

# from source.extract_patches import create_patch_dataset

# patches_npy_path = join(root_dir, 'results', 'patches', 'training.npy')

# # Extracts patches from whole-slide images and store them in a numpy array file
# create_patch_dataset(
#     input_dir=slide_dir,
#     csv_path=csv_path,
#     partition_tag='encoder',
#     output_path=patches_npy_path,
#     image_level=2,
#     patch_size=96,
#     n_patches_per_image=10000,
#     cache_dir=join(cache_dir, 'patches')
# )

# %% [markdown]
# Once we have extracted the patches, we can proceed to train the BiGAN model. We will use the hyper-parameters described in the NIC paper.

# %%
# from source.train_bigan_model import BiganModel

# model_bigan_dir = join(root_dir, 'results', 'encoders', 'bigan', 'rotterdam1_96_noaug', '0.0001')

# # Trains BiGAN
# bigan = BiganModel(
#     latent_dim=128,
#     n_filters=128,
#     lr=0.0001,
#     patch_size=64,
# )
# bigan.train(
#     x_path=patches_npy_path,
#     output_dir=model_bigan_dir,
#     epochs=400000,
#     batch_size=64,
#     sample_interval=1000,
#     save_models_on_epoch=True
# )

# %% [markdown]
# Beware that training this model is highly unstable, thus it can fail or collapse with ease. If this happens, restart the training. Selecting a checkpoint model is a manual procedure: check the generated images and loss values and avoid abnormal results.

# %% [markdown]
# ## 2. Compress images ##
#
# Once we have a trained encoder, we can proceed with the WSI compression. I recommend running several `IDLE` instances of the following code in the cluster to speed up the lenghty process.

# %% [markdown]
# Before the actual compression, we need to vectorize the WSIs. This process extracts all non-background patches from the slide and store them in numpy array format for quick access. In this case, we will read 64x64 patches at 1 um/px resolution (level 2).

# %%
# Vectorize LUAD WSIs
from vectorize_wsi import vectorize_images

vectorize_images(
    input_dir=dir_luad_wsi,
    mask_dir=dir_luad_wsi_mask, 
    output_dir=vectorized_luad_dir, 
    cache_dir=cache_dir, 
    image_level=2, 
    patch_size=128
    )
# Out:
# Already existing file TCGA-05-4244-01Z-00-DX1 - 530 images left
# Already existing file TCGA-05-4245-01Z-00-DX1 - 529 images left
# Already existing file TCGA-05-4249-01Z-00-DX1 - 528 images left
# Already existing file TCGA-05-4250-01Z-00-DX1 - 527 images left
# Already existing file TCGA-05-4382-01Z-00-DX1 - 526 images left
# Already existing file TCGA-05-4395-01Z-00-DX1 - 525 images left
# Already existing file TCGA-05-4396-01Z-00-DX1 - 524 images left
# Already existing file TCGA-05-4397-01Z-00-DX1 - 523 images left
# Already existing file TCGA-05-4398-01Z-00-DX1 - 522 images left
# Already existing file TCGA-05-4402-01Z-00-DX1 - 521 images left
# Already existing file TCGA-05-4403-01Z-00-DX1 - 520 images left
# Already existing file TCGA-05-4405-01Z-00-DX1 - 519 images left
# Already existing file TCGA-05-4415-01Z-00-DX1 - 518 images left
# Already existing file TCGA-05-4417-01Z-00-DX1 - 517 images left
# Already existing file TCGA-05-4418-01Z-00-DX1 - 516 images left
# Already existing file TCGA-05-4420-01Z-00-DX1 - 515 images left
# Already existing file TCGA-05-4422-01Z-00-DX1 - 514 images left
# Already existing file TCGA-05-4424-01Z-00-DX1 - 513 images left
# Already existing file TCGA-05-4426-01Z-00-DX1 - 512 images left
# Already existing file TCGA-05-4427-01Z-00-DX1 - 511 images left
# Already existing file TCGA-05-4430-01Z-00-DX1 - 510 images left
# Already existing file TCGA-05-4432-01Z-00-DX1 - 509 images left
# Already existing file TCGA-05-4433-01Z-00-DX1 - 508 images left
# Already existing file TCGA-05-4434-01Z-00-DX1 - 507 images left
# Already existing file TCGA-35-3615-01Z-00-DX1 - 506 images left
# Already existing file TCGA-35-4122-01Z-00-DX1 - 505 images left
# Already existing file TCGA-35-4123-01Z-00-DX1 - 504 images left
# Already existing file TCGA-35-5375-01Z-00-DX1 - 503 images left
# Already existing file TCGA-38-4625-01Z-00-DX1 - 502 images left
# Already existing file TCGA-38-4626-01Z-00-DX1 - 501 images left
# Already existing file TCGA-38-4627-01Z-00-DX1 - 500 images left
# Already existing file TCGA-38-4628-01Z-00-DX1 - 499 images left
# Already existing file TCGA-38-4629-01Z-00-DX1 - 498 images left
# Already existing file TCGA-38-4630-01Z-00-DX1 - 497 images left
# Already existing file TCGA-38-4631-01Z-00-DX1 - 496 images left
# Already existing file TCGA-38-4632-01Z-00-DX1 - 495 images left
# Already existing file TCGA-38-6178-01Z-00-DX1 - 494 images left
# Already existing file TCGA-38-7271-01Z-00-DX1 - 493 images left
# Already existing file TCGA-38-A44F-01Z-00-DX1 - 492 images left
# Already existing file TCGA-44-2655-01Z-00-DX1 - 491 images left
# Already existing file TCGA-44-2656-01Z-00-DX1 - 490 images left
# Already existing file TCGA-44-2657-01Z-00-DX1 - 489 images left
# Already existing file TCGA-44-2659-01Z-00-DX1 - 488 images left
# Already existing file TCGA-44-2661-01Z-00-DX1 - 487 images left
# Already existing file TCGA-44-2662-01Z-00-DX1 - 486 images left
# Already existing file TCGA-44-2664-01Z-00-DX1 - 485 images left
# Already existing file TCGA-44-2665-01Z-00-DX1 - 484 images left
# Already existing file TCGA-44-2666-01Z-00-DX1 - 483 images left
# Already existing file TCGA-44-2668-01Z-00-DX1 - 482 images left
# Already existing file TCGA-44-3396-01Z-00-DX1 - 481 images left
# Already existing file TCGA-44-3398-01Z-00-DX1 - 480 images left
# Already existing file TCGA-44-3917-01Z-00-DX1 - 479 images left
# Already existing file TCGA-44-3918-01Z-00-DX1 - 478 images left
# Already existing file TCGA-44-3919-01Z-00-DX1 - 477 images left
# Already existing file TCGA-44-4112-01Z-00-DX1 - 476 images left
# Already existing file TCGA-44-5643-01Z-00-DX1 - 475 images left
# Already existing file TCGA-44-5644-01Z-00-DX1 - 474 images left
# Already existing file TCGA-44-5645-01Z-00-DX1 - 473 images left
# Already existing file TCGA-44-6144-01Z-00-DX1 - 472 images left
# Already existing file TCGA-44-6145-01Z-00-DX1 - 471 images left
# Already existing file TCGA-44-6146-01Z-00-DX1 - 470 images left
# Already existing file TCGA-44-6147-01Z-00-DX1 - 469 images left
# Already existing file TCGA-44-6148-01Z-00-DX1 - 468 images left
# Already existing file TCGA-44-6774-01Z-00-DX1 - 467 images left
# Already existing file TCGA-44-6775-01Z-00-DX1 - 466 images left
# Already existing file TCGA-44-6776-01Z-00-DX1 - 465 images left
# Already existing file TCGA-44-6777-01Z-00-DX1 - 464 images left
# Already existing file TCGA-44-6778-01Z-00-DX1 - 463 images left
# Already existing file TCGA-44-6779-01Z-00-DX1 - 462 images left
# Already existing file TCGA-44-7659-01Z-00-DX1 - 461 images left
# Already existing file TCGA-44-7660-01Z-00-DX1 - 460 images left
# Already existing file TCGA-44-7661-01Z-00-DX1 - 459 images left
# Already existing file TCGA-44-7662-01Z-00-DX1 - 458 images left
# Already existing file TCGA-44-7667-01Z-00-DX1 - 457 images left
# Already existing file TCGA-44-7669-01Z-00-DX1 - 456 images left
# Already existing file TCGA-44-7670-01Z-00-DX1 - 455 images left
# Already existing file TCGA-44-7671-01Z-00-DX1 - 454 images left
# Already existing file TCGA-44-7672-01Z-00-DX1 - 453 images left
# Already existing file TCGA-44-8119-01Z-00-DX1 - 452 images left
# Already existing file TCGA-44-A479-01Z-00-DX1 - 451 images left
# Already existing file TCGA-44-A47A-01Z-00-DX1 - 450 images left
# Already existing file TCGA-44-A47B-01Z-00-DX1 - 449 images left
# Already existing file TCGA-44-A47F-01Z-00-DX1 - 448 images left
# Already existing file TCGA-44-A47G-01Z-00-DX1 - 447 images left
# Already existing file TCGA-44-A4SS-01Z-00-DX1 - 446 images left
# Already existing file TCGA-44-A4SU-01Z-00-DX1 - 445 images left
# Already existing file TCGA-49-4487-01Z-00-DX1 - 444 images left
# Already existing file TCGA-49-4488-01Z-00-DX1 - 443 images left
# Already existing file TCGA-49-4488-01Z-00-DX10 - 442 images left
# Already existing file TCGA-49-4488-01Z-00-DX2 - 441 images left
# Already existing file TCGA-49-4488-01Z-00-DX3 - 440 images left
# Already existing file TCGA-49-4488-01Z-00-DX4 - 439 images left
# Already existing file TCGA-49-4488-01Z-00-DX5 - 438 images left
# Already existing file TCGA-49-4488-01Z-00-DX6 - 437 images left
# Already existing file TCGA-49-4488-01Z-00-DX7 - 436 images left
# Already existing file TCGA-49-4488-01Z-00-DX8 - 435 images left
# Already existing file TCGA-49-4488-01Z-00-DX9 - 434 images left
# Already existing file TCGA-49-4490-01Z-00-DX1 - 433 images left
# Already existing file TCGA-49-4490-01Z-00-DX2 - 432 images left
# Already existing file TCGA-49-4490-01Z-00-DX3 - 431 images left
# Already existing file TCGA-49-4490-01Z-00-DX4 - 430 images left
# Already existing file TCGA-49-4490-01Z-00-DX5 - 429 images left
# Already existing file TCGA-49-4490-01Z-00-DX6 - 428 images left
# Already existing file TCGA-49-4494-01Z-00-DX1 - 427 images left
# Already existing file TCGA-49-4494-01Z-00-DX2 - 426 images left
# Already existing file TCGA-49-4494-01Z-00-DX3 - 425 images left
# Already existing file TCGA-49-4494-01Z-00-DX4 - 424 images left
# Already existing file TCGA-49-4494-01Z-00-DX5 - 423 images left
# Already existing file TCGA-49-4494-01Z-00-DX6 - 422 images left
# Already existing file TCGA-49-4494-01Z-00-DX7 - 421 images left
# Already existing file TCGA-49-4501-01Z-00-DX1 - 420 images left
# Already existing file TCGA-49-4501-01Z-00-DX2 - 419 images left
# Already existing file TCGA-49-4501-01Z-00-DX3 - 418 images left
# Already existing file TCGA-49-4505-01Z-00-DX1 - 417 images left
# Already existing file TCGA-49-4505-01Z-00-DX2 - 416 images left
# Already existing file TCGA-49-4505-01Z-00-DX3 - 415 images left
# Already existing file TCGA-49-4505-01Z-00-DX4 - 414 images left
# Already existing file TCGA-49-4506-01Z-00-DX1 - 413 images left
# Already existing file TCGA-49-4506-01Z-00-DX2 - 412 images left
# Already existing file TCGA-49-4506-01Z-00-DX3 - 411 images left
# Already existing file TCGA-49-4506-01Z-00-DX4 - 410 images left
# Already existing file TCGA-49-4507-01Z-00-DX1 - 409 images left
# Already existing file TCGA-49-4507-01Z-00-DX2 - 408 images left
# Already existing file TCGA-49-4510-01Z-00-DX1 - 407 images left
# Already existing file TCGA-49-4510-01Z-00-DX2 - 406 images left
# Already existing file TCGA-49-4512-01Z-00-DX1 - 405 images left
# Already existing file TCGA-49-4512-01Z-00-DX2 - 404 images left
# Already existing file TCGA-49-4512-01Z-00-DX3 - 403 images left
# Already existing file TCGA-49-4512-01Z-00-DX4 - 402 images left
# Already existing file TCGA-49-4512-01Z-00-DX5 - 401 images left
# Already existing file TCGA-49-4512-01Z-00-DX6 - 400 images left
# Already existing file TCGA-49-4512-01Z-00-DX7 - 399 images left
# Already existing file TCGA-49-4512-01Z-00-DX8 - 398 images left
# Already existing file TCGA-49-4514-01Z-00-DX1 - 397 images left
# Already existing file TCGA-49-4514-01Z-00-DX2 - 396 images left
# Already existing file TCGA-49-4514-01Z-00-DX3 - 395 images left
# Already existing file TCGA-49-4514-01Z-00-DX4 - 394 images left
# Already existing file TCGA-49-6742-01Z-00-DX1 - 393 images left
# Already existing file TCGA-49-6742-01Z-00-DX2 - 392 images left
# Already existing file TCGA-49-6742-01Z-00-DX3 - 391 images left
# Already existing file TCGA-49-6742-01Z-00-DX4 - 390 images left
# Already existing file TCGA-49-6742-01Z-00-DX5 - 389 images left
# Already existing file TCGA-49-6743-01Z-00-DX1 - 388 images left
# Already existing file TCGA-49-6743-01Z-00-DX2 - 387 images left
# Already existing file TCGA-49-6743-01Z-00-DX3 - 386 images left
# Already existing file TCGA-49-6743-01Z-00-DX4 - 385 images left
# Already existing file TCGA-49-6744-01Z-00-DX1 - 384 images left
# Already existing file TCGA-49-6744-01Z-00-DX2 - 383 images left
# Already existing file TCGA-49-6744-01Z-00-DX3 - 382 images left
# Already existing file TCGA-49-6744-01Z-00-DX4 - 381 images left
# Already existing file TCGA-49-6745-01Z-00-DX1 - 380 images left
# Already existing file TCGA-49-6745-01Z-00-DX2 - 379 images left
# Already existing file TCGA-49-6745-01Z-00-DX3 - 378 images left
# Already existing file TCGA-49-6745-01Z-00-DX4 - 377 images left
# Already existing file TCGA-49-6745-01Z-00-DX5 - 376 images left
# Already existing file TCGA-49-6745-01Z-00-DX6 - 375 images left
# Already existing file TCGA-49-6745-01Z-00-DX7 - 374 images left
# Already existing file TCGA-49-6761-01Z-00-DX1 - 373 images left
# Already existing file TCGA-49-6767-01Z-00-DX1 - 372 images left
# Already existing file TCGA-49-AAQV-01Z-00-DX1 - 371 images left
# Already existing file TCGA-49-AAR0-01Z-00-DX1 - 370 images left
# Already existing file TCGA-49-AAR2-01Z-00-DX1 - 369 images left
# Already existing file TCGA-49-AAR3-01Z-00-DX1 - 368 images left
# Already existing file TCGA-49-AAR4-01Z-00-DX1 - 367 images left
# Already existing file TCGA-49-AAR9-01Z-00-DX1 - 366 images left
# Already existing file TCGA-49-AARE-01Z-00-DX1 - 365 images left
# Already existing file TCGA-49-AARN-01Z-00-DX1 - 364 images left
# Already existing file TCGA-49-AARO-01Z-00-DX1 - 363 images left
# Already existing file TCGA-49-AARQ-01Z-00-DX1 - 362 images left
# Already existing file TCGA-49-AARR-01Z-00-DX1 - 361 images left
# Already existing file TCGA-4B-A93V-01Z-00-DX1 - 360 images left
# Already existing file TCGA-50-5044-01Z-00-DX1 - 359 images left
# Already existing file TCGA-50-5045-01Z-00-DX1 - 358 images left
# Already existing file TCGA-50-5045-01Z-00-DX2 - 357 images left
# Already existing file TCGA-50-5055-01Z-00-DX1 - 356 images left
# Already existing file TCGA-50-5055-01Z-00-DX2 - 355 images left
# Already existing file TCGA-50-5066-01Z-00-DX1 - 354 images left
# Already existing file TCGA-50-5066-02Z-00-DX1 - 353 images left
# Already existing file TCGA-50-5068-01Z-00-DX1 - 352 images left
# Already existing file TCGA-50-5068-01Z-00-DX2 - 351 images left
# Already existing file TCGA-50-5931-01Z-00-DX1 - 350 images left
# Already existing file TCGA-50-5939-01Z-00-DX1 - 349 images left
# Already existing file TCGA-50-5942-01Z-00-DX1 - 348 images left
# Already existing file TCGA-50-5946-01Z-00-DX1 - 347 images left
# Already existing file TCGA-50-6590-01Z-00-DX1 - 346 images left
# Already existing file TCGA-50-6591-01Z-00-DX1 - 345 images left
# Already existing file TCGA-50-6593-01Z-00-DX1 - 344 images left
# Already existing file TCGA-50-6594-01Z-00-DX1 - 343 images left
# Already existing file TCGA-50-6597-01Z-00-DX1 - 342 images left
# Already existing file TCGA-50-6673-01Z-00-DX1 - 341 images left
# Already existing file TCGA-50-7109-01Z-00-DX1 - 340 images left
# Already existing file TCGA-50-8457-01Z-00-DX1 - 339 images left
# Already existing file TCGA-50-8459-01Z-00-DX1 - 338 images left
# Already existing file TCGA-53-7624-01Z-00-DX1 - 337 images left
# Already existing file TCGA-53-7626-01Z-00-DX1 - 336 images left
# Already existing file TCGA-53-7813-01Z-00-DX1 - 335 images left
# Already existing file TCGA-53-A4EZ-01Z-00-DX1 - 334 images left
# Already existing file TCGA-55-1592-01Z-00-DX1 - 333 images left
# Already existing file TCGA-55-1594-01Z-00-DX1 - 332 images left
# Already existing file TCGA-55-1595-01Z-00-DX1 - 331 images left
# Already existing file TCGA-55-1596-01Z-00-DX1 - 330 images left
# Already existing file TCGA-55-5899-01Z-00-DX1 - 329 images left
# Already existing file TCGA-55-6543-01Z-00-DX1 - 328 images left
# Already existing file TCGA-55-6642-01Z-00-DX1 - 327 images left
# Already existing file TCGA-55-6712-01Z-00-DX1 - 326 images left
# Already existing file TCGA-55-6968-01Z-00-DX1 - 325 images left
# Already existing file TCGA-55-6969-01Z-00-DX1 - 324 images left
# Already existing file TCGA-55-6970-01Z-00-DX1 - 323 images left
# Already existing file TCGA-55-6971-01Z-00-DX1 - 322 images left
# Already existing file TCGA-55-6972-01Z-00-DX1 - 321 images left
# Already existing file TCGA-55-6975-01Z-00-DX1 - 320 images left
# Already existing file TCGA-55-6978-01Z-00-DX1 - 319 images left
# Already existing file TCGA-55-6979-01Z-00-DX1 - 318 images left
# Already existing file TCGA-55-6980-01Z-00-DX1 - 317 images left
# Already existing file TCGA-55-6981-01Z-00-DX1 - 316 images left
# Already existing file TCGA-55-6982-01Z-00-DX1 - 315 images left
# Already existing file TCGA-55-6983-01Z-00-DX1 - 314 images left
# Already existing file TCGA-55-6984-01Z-00-DX1 - 313 images left
# Already existing file TCGA-55-6985-01Z-00-DX1 - 312 images left
# Already existing file TCGA-55-6986-01Z-00-DX1 - 311 images left
# Already existing file TCGA-55-6987-01Z-00-DX1 - 310 images left
# Already existing file TCGA-55-7227-01Z-00-DX1 - 309 images left
# Already existing file TCGA-55-7281-01Z-00-DX1 - 308 images left
# Already existing file TCGA-55-7283-01Z-00-DX1 - 307 images left
# Already existing file TCGA-55-7284-01Z-00-DX1 - 306 images left
# Already existing file TCGA-55-7570-01Z-00-DX1 - 305 images left
# Already existing file TCGA-55-7573-01Z-00-DX1 - 304 images left
# Already existing file TCGA-55-7574-01Z-00-DX1 - 303 images left
# Already existing file TCGA-55-7576-01Z-00-DX1 - 302 images left
# Already existing file TCGA-55-7724-01Z-00-DX1 - 301 images left
# Already existing file TCGA-55-7725-01Z-00-DX1 - 300 images left
# Already existing file TCGA-55-7726-01Z-00-DX1 - 299 images left
# Already existing file TCGA-55-7727-01Z-00-DX1 - 298 images left
# Already existing file TCGA-55-7728-01Z-00-DX1 - 297 images left
# Already existing file TCGA-55-7815-01Z-00-DX1 - 296 images left
# Already existing file TCGA-55-7816-01Z-00-DX1 - 295 images left
# Already existing file TCGA-55-7903-01Z-00-DX1 - 294 images left
# Already existing file TCGA-55-7907-01Z-00-DX1 - 293 images left
# Already existing file TCGA-55-7910-01Z-00-DX1 - 292 images left
# Already existing file TCGA-55-7911-01Z-00-DX1 - 291 images left
# Already existing file TCGA-55-7913-01Z-00-DX1 - 290 images left
# Already existing file TCGA-55-7914-01Z-00-DX1 - 289 images left
# Already existing file TCGA-55-7994-01Z-00-DX1 - 288 images left
# Already existing file TCGA-55-7995-01Z-00-DX1 - 287 images left
# Already existing file TCGA-55-8085-01Z-00-DX1 - 286 images left
# Already existing file TCGA-55-8087-01Z-00-DX1 - 285 images left
# Already existing file TCGA-55-8089-01Z-00-DX1 - 284 images left
# Already existing file TCGA-55-8090-01Z-00-DX1 - 283 images left
# Already existing file TCGA-55-8091-01Z-00-DX1 - 282 images left
# Already existing file TCGA-55-8092-01Z-00-DX1 - 281 images left
# Already existing file TCGA-55-8094-01Z-00-DX1 - 280 images left
# Already existing file TCGA-55-8096-01Z-00-DX1 - 279 images left
# Already existing file TCGA-55-8097-01Z-00-DX1 - 278 images left
# Already existing file TCGA-55-8203-01Z-00-DX1 - 277 images left
# Already existing file TCGA-55-8204-01Z-00-DX1 - 276 images left
# Already existing file TCGA-55-8205-01Z-00-DX1 - 275 images left
# Already existing file TCGA-55-8206-01Z-00-DX1 - 274 images left
# Already existing file TCGA-55-8207-01Z-00-DX1 - 273 images left
# Already existing file TCGA-55-8208-01Z-00-DX1 - 272 images left
# Already existing file TCGA-55-8299-01Z-00-DX1 - 271 images left
# Already existing file TCGA-55-8301-01Z-00-DX1 - 270 images left
# Already existing file TCGA-55-8302-01Z-00-DX1 - 269 images left
# Already existing file TCGA-55-8505-01Z-00-DX1 - 268 images left
# Already existing file TCGA-55-8506-01Z-00-DX1 - 267 images left
# Already existing file TCGA-55-8507-01Z-00-DX1 - 266 images left
# Already existing file TCGA-55-8508-01Z-00-DX1 - 265 images left
# Already existing file TCGA-55-8510-01Z-00-DX1 - 264 images left
# Already existing file TCGA-55-8511-01Z-00-DX1 - 263 images left
# Already existing file TCGA-55-8512-01Z-00-DX1 - 262 images left
# Already existing file TCGA-55-8513-01Z-00-DX1 - 261 images left
# Already existing file TCGA-55-8514-01Z-00-DX1 - 260 images left
# Already existing file TCGA-55-8614-01Z-00-DX1 - 259 images left
# Already existing file TCGA-55-8615-01Z-00-DX1 - 258 images left
# Already existing file TCGA-55-8616-01Z-00-DX1 - 257 images left
# Already existing file TCGA-55-8619-01Z-00-DX1 - 256 images left
# Already existing file TCGA-55-8620-01Z-00-DX1 - 255 images left
# Already existing file TCGA-55-8621-01Z-00-DX1 - 254 images left
# Already existing file TCGA-55-A48X-01Z-00-DX1 - 253 images left
# Already existing file TCGA-55-A48Y-01Z-00-DX1 - 252 images left
# Already existing file TCGA-55-A48Z-01Z-00-DX1 - 251 images left
# Already existing file TCGA-55-A490-01Z-00-DX1 - 250 images left
# Already existing file TCGA-55-A491-01Z-00-DX1 - 249 images left
# Already existing file TCGA-55-A492-01Z-00-DX1 - 248 images left
# Already existing file TCGA-55-A493-01Z-00-DX1 - 247 images left
# Already existing file TCGA-55-A494-01Z-00-DX1 - 246 images left
# Already existing file TCGA-55-A4DF-01Z-00-DX1 - 245 images left
# Already existing file TCGA-55-A4DG-01Z-00-DX1 - 244 images left
# Already existing file TCGA-55-A57B-01Z-00-DX1 - 243 images left
# Already existing file TCGA-62-A46O-01Z-00-DX1 - 242 images left
# Already existing file TCGA-62-A46P-01Z-00-DX1 - 241 images left
# Already existing file TCGA-62-A46R-01Z-00-DX1 - 240 images left
# Already existing file TCGA-62-A46S-01Z-00-DX1 - 239 images left
# Already existing file TCGA-62-A46U-01Z-00-DX1 - 238 images left
# Already existing file TCGA-62-A46V-01Z-00-DX1 - 237 images left
# Already existing file TCGA-62-A470-01Z-00-DX1 - 236 images left
# Already existing file TCGA-62-A471-01Z-00-DX1 - 235 images left
# Already existing file TCGA-62-A472-01Z-00-DX1 - 234 images left
# Already existing file TCGA-64-1676-01Z-00-DX1 - 233 images left
# Already existing file TCGA-64-1677-01Z-00-DX1 - 232 images left
# Already existing file TCGA-64-1678-01Z-00-DX1 - 231 images left
# Already existing file TCGA-64-1679-01Z-00-DX1 - 230 images left
# Already existing file TCGA-64-1680-01Z-00-DX1 - 229 images left
# Already existing file TCGA-64-1681-01Z-00-DX1 - 228 images left
# Already existing file TCGA-64-5774-01Z-00-DX1 - 227 images left
# Already existing file TCGA-64-5775-01Z-00-DX1 - 226 images left
# Already existing file TCGA-64-5778-01Z-00-DX1 - 225 images left
# Already existing file TCGA-64-5779-01Z-00-DX1 - 224 images left
# Already existing file TCGA-64-5781-01Z-00-DX1 - 223 images left
# Already existing file TCGA-64-5815-01Z-00-DX1 - 222 images left
# Already existing file TCGA-67-3770-01Z-00-DX1 - 221 images left
# Already existing file TCGA-67-3771-01Z-00-DX1 - 220 images left
# Already existing file TCGA-67-3772-01Z-00-DX1 - 219 images left
# Already existing file TCGA-67-3773-01Z-00-DX1 - 218 images left
# Already existing file TCGA-67-3774-01Z-00-DX1 - 217 images left
# Already existing file TCGA-67-4679-01Z-00-DX1 - 216 images left
# Already existing file TCGA-67-6215-01Z-00-DX1 - 215 images left
# Already existing file TCGA-67-6216-01Z-00-DX1 - 214 images left
# Already existing file TCGA-67-6217-01Z-00-DX1 - 213 images left
# Already existing file TCGA-69-7760-01Z-00-DX1 - 212 images left
# Already existing file TCGA-69-7761-01Z-00-DX1 - 211 images left
# Already existing file TCGA-69-7763-01Z-00-DX1 - 210 images left
# Already existing file TCGA-69-7764-01Z-00-DX1 - 209 images left
# Already existing file TCGA-69-7765-01Z-00-DX1 - 208 images left
# Already existing file TCGA-69-7973-01Z-00-DX1 - 207 images left
# Already existing file TCGA-69-7974-01Z-00-DX1 - 206 images left
# Already existing file TCGA-69-7978-01Z-00-DX1 - 205 images left
# Already existing file TCGA-69-7979-01Z-00-DX1 - 204 images left
# Already existing file TCGA-69-7980-01Z-00-DX1 - 203 images left
# Already existing file TCGA-69-8253-01Z-00-DX1 - 202 images left
# Already existing file TCGA-69-8254-01Z-00-DX1 - 201 images left
# Already existing file TCGA-69-8255-01Z-00-DX1 - 200 images left
# Already existing file TCGA-69-8453-01Z-00-DX1 - 199 images left
# Already existing file TCGA-69-A59K-01Z-00-DX1 - 198 images left
# Already existing file TCGA-71-6725-01Z-00-DX1 - 197 images left
# Already existing file TCGA-71-8520-01Z-00-DX1 - 196 images left
# Already existing file TCGA-73-4658-01Z-00-DX1 - 195 images left
# Already existing file TCGA-73-4659-01Z-00-DX1 - 194 images left
# Already existing file TCGA-73-4662-01Z-00-DX1 - 193 images left
# Already existing file TCGA-73-4666-01Z-00-DX1 - 192 images left
# Already existing file TCGA-73-4668-01Z-00-DX1 - 191 images left
# Already existing file TCGA-73-4670-01Z-00-DX1 - 190 images left
# Already existing file TCGA-73-4675-01Z-00-DX1 - 189 images left
# Already existing file TCGA-73-4676-01Z-00-DX1 - 188 images left
# Already existing file TCGA-73-4677-01Z-00-DX1 - 187 images left
# Already existing file TCGA-73-7498-01Z-00-DX1 - 186 images left
# Already existing file TCGA-73-7499-01Z-00-DX1 - 185 images left
# Already existing file TCGA-73-A9RS-01Z-00-DX1 - 184 images left
# Already existing file TCGA-75-5122-01Z-00-DX1 - 183 images left
# Already existing file TCGA-75-5125-01Z-00-DX1 - 182 images left
# Already existing file TCGA-75-5126-01Z-00-DX1 - 181 images left
# Already existing file TCGA-75-5146-01Z-00-DX1 - 180 images left
# Already existing file TCGA-75-5147-01Z-00-DX1 - 179 images left
# Already existing file TCGA-75-6203-01Z-00-DX1 - 178 images left
# Already existing file TCGA-75-6205-01Z-00-DX1 - 177 images left
# Already existing file TCGA-75-6206-01Z-00-DX1 - 176 images left
# Already existing file TCGA-75-6207-01Z-00-DX1 - 175 images left
# Already existing file TCGA-75-6211-01Z-00-DX1 - 174 images left
# Already existing file TCGA-75-6212-01Z-00-DX1 - 173 images left
# Already existing file TCGA-75-6214-01Z-00-DX1 - 172 images left
# Already existing file TCGA-75-7025-01Z-00-DX1 - 171 images left
# Already existing file TCGA-75-7027-01Z-00-DX1 - 170 images left
# Already existing file TCGA-75-7030-01Z-00-DX1 - 169 images left
# Already existing file TCGA-75-7031-01Z-00-DX1 - 168 images left
# Already existing file TCGA-78-7145-01Z-00-DX1 - 167 images left
# Already existing file TCGA-78-7146-01Z-00-DX1 - 166 images left
# Already existing file TCGA-78-7147-01Z-00-DX1 - 165 images left
# Already existing file TCGA-78-7148-01Z-00-DX1 - 164 images left
# Already existing file TCGA-78-7149-01Z-00-DX1 - 163 images left
# Already existing file TCGA-78-7150-01Z-00-DX1 - 162 images left
# Already existing file TCGA-78-7152-01Z-00-DX1 - 161 images left
# Already existing file TCGA-78-7153-01Z-00-DX1 - 160 images left
# Already existing file TCGA-78-7154-01Z-00-DX1 - 159 images left
# Already existing file TCGA-78-7155-01Z-00-DX1 - 158 images left
# Already existing file TCGA-78-7156-01Z-00-DX1 - 157 images left
# Already existing file TCGA-78-7158-01Z-00-DX1 - 156 images left
# Already existing file TCGA-78-7159-01Z-00-DX1 - 155 images left
# Already existing file TCGA-78-7160-01Z-00-DX1 - 154 images left
# Already existing file TCGA-78-7161-01Z-00-DX1 - 153 images left
# Already existing file TCGA-78-7163-01Z-00-DX1 - 152 images left
# Already existing file TCGA-78-7166-01Z-00-DX1 - 151 images left
# Already existing file TCGA-78-7167-01Z-00-DX1 - 150 images left
# Already existing file TCGA-78-7220-01Z-00-DX1 - 149 images left
# Already existing file TCGA-78-7535-01Z-00-DX1 - 148 images left
# Already existing file TCGA-78-7536-01Z-00-DX1 - 147 images left
# Already existing file TCGA-78-7537-01Z-00-DX1 - 146 images left
# Already existing file TCGA-78-7539-01Z-00-DX1 - 145 images left
# Already existing file TCGA-78-7540-01Z-00-DX1 - 144 images left
# Already existing file TCGA-78-7542-01Z-00-DX1 - 143 images left
# Already existing file TCGA-78-7633-01Z-00-DX1 - 142 images left
# Already existing file TCGA-78-8640-01Z-00-DX1 - 141 images left
# Already existing file TCGA-78-8648-01Z-00-DX1 - 140 images left
# Already existing file TCGA-78-8655-01Z-00-DX1 - 139 images left
# Already existing file TCGA-78-8660-01Z-00-DX1 - 138 images left
# Already existing file TCGA-78-8662-01Z-00-DX1 - 137 images left
# Already existing file TCGA-80-5607-01Z-00-DX1 - 136 images left
# Already existing file TCGA-80-5608-01Z-00-DX1 - 135 images left
# Already existing file TCGA-80-5611-01Z-00-DX1 - 134 images left
# Already existing file TCGA-83-5908-01Z-00-DX1 - 133 images left
# Already existing file TCGA-86-6562-01Z-00-DX1 - 132 images left
# Already existing file TCGA-86-6851-01Z-00-DX1 - 131 images left
# Already existing file TCGA-86-7701-01Z-00-DX1 - 130 images left
# Already existing file TCGA-86-7711-01Z-00-DX1 - 129 images left
# Already existing file TCGA-86-7713-01Z-00-DX1 - 128 images left
# Already existing file TCGA-86-7714-01Z-00-DX1 - 127 images left
# Already existing file TCGA-86-7953-01Z-00-DX1 - 126 images left
# Already existing file TCGA-86-7954-01Z-00-DX1 - 125 images left
# Already existing file TCGA-86-7955-01Z-00-DX1 - 124 images left
# Already existing file TCGA-86-8054-01Z-00-DX1 - 123 images left
# Already existing file TCGA-86-8055-01Z-00-DX1 - 122 images left
# Already existing file TCGA-86-8056-01Z-00-DX1 - 121 images left
# Already existing file TCGA-86-8073-01Z-00-DX1 - 120 images left
# Already existing file TCGA-86-8074-01Z-00-DX1 - 119 images left
# Already existing file TCGA-86-8075-01Z-00-DX1 - 118 images left
# Already existing file TCGA-86-8076-01Z-00-DX1 - 117 images left
# Already existing file TCGA-86-8278-01Z-00-DX1 - 116 images left
# Already existing file TCGA-86-8279-01Z-00-DX1 - 115 images left
# Already existing file TCGA-86-8280-01Z-00-DX1 - 114 images left
# Already existing file TCGA-86-8281-01Z-00-DX1 - 113 images left
# Already existing file TCGA-86-8358-01Z-00-DX1 - 112 images left
# Already existing file TCGA-86-8359-01Z-00-DX1 - 111 images left
# Already existing file TCGA-86-8585-01Z-00-DX1 - 110 images left
# Already existing file TCGA-86-8668-01Z-00-DX1 - 109 images left
# Already existing file TCGA-86-8669-01Z-00-DX1 - 108 images left
# Already existing file TCGA-86-8671-01Z-00-DX1 - 107 images left
# Already existing file TCGA-86-8672-01Z-00-DX1 - 106 images left
# Already existing file TCGA-86-8673-01Z-00-DX1 - 105 images left
# Already existing file TCGA-86-8674-01Z-00-DX1 - 104 images left
# Already existing file TCGA-86-A456-01Z-00-DX1 - 103 images left
# Already existing file TCGA-86-A4D0-01Z-00-DX1 - 102 images left
# Already existing file TCGA-86-A4JF-01Z-00-DX1 - 101 images left
# Already existing file TCGA-86-A4P7-01Z-00-DX1 - 100 images left
# Already existing file TCGA-86-A4P8-01Z-00-DX1 - 99 images left
# Already existing file TCGA-91-A4BC-01Z-00-DX1 - 98 images left
# Already existing file TCGA-91-A4BD-01Z-00-DX1 - 97 images left
# Already existing file TCGA-93-7347-01Z-00-DX1 - 96 images left
# Already existing file TCGA-93-7348-01Z-00-DX1 - 95 images left
# Already existing file TCGA-93-8067-01Z-00-DX1 - 94 images left
# Already existing file TCGA-93-A4JN-01Z-00-DX1 - 93 images left
# Already existing file TCGA-93-A4JO-01Z-00-DX1 - 92 images left
# Already existing file TCGA-93-A4JP-01Z-00-DX1 - 91 images left
# Already existing file TCGA-93-A4JQ-01Z-00-DX1 - 90 images left
# Already existing file TCGA-95-7039-01Z-00-DX1 - 89 images left
# Already existing file TCGA-95-7043-01Z-00-DX1 - 88 images left
# Already existing file TCGA-95-7562-01Z-00-DX1 - 87 images left
# Already existing file TCGA-95-7567-01Z-00-DX1 - 86 images left
# Already existing file TCGA-95-7944-01Z-00-DX1 - 85 images left
# Already existing file TCGA-95-7947-01Z-00-DX1 - 84 images left
# Already existing file TCGA-95-7948-01Z-00-DX1 - 83 images left
# Already existing file TCGA-95-8039-01Z-00-DX1 - 82 images left
# Already existing file TCGA-95-8494-01Z-00-DX1 - 81 images left
# Already existing file TCGA-95-A4VK-01Z-00-DX1 - 80 images left
# Already existing file TCGA-95-A4VN-01Z-00-DX1 - 79 images left
# Already existing file TCGA-95-A4VP-01Z-00-DX1 - 78 images left
# Already existing file TCGA-97-7546-01Z-00-DX1 - 77 images left
# Already existing file TCGA-97-7547-01Z-00-DX1 - 76 images left
# Already existing file TCGA-97-7552-01Z-00-DX1 - 75 images left
# Already existing file TCGA-97-7553-01Z-00-DX1 - 74 images left
# Already existing file TCGA-97-7554-01Z-00-DX1 - 73 images left
# Already existing file TCGA-97-7937-01Z-00-DX1 - 72 images left
# Already existing file TCGA-97-7938-01Z-00-DX1 - 71 images left
# Already existing file TCGA-97-7941-01Z-00-DX1 - 70 images left
# Already existing file TCGA-97-8171-01Z-00-DX1 - 69 images left
# Already existing file TCGA-97-8172-01Z-00-DX1 - 68 images left
# Already existing file TCGA-97-8175-01Z-00-DX1 - 67 images left
# Already existing file TCGA-97-8177-01Z-00-DX1 - 66 images left
# Already existing file TCGA-97-8179-01Z-00-DX1 - 65 images left
# Already existing file TCGA-97-8552-01Z-00-DX1 - 64 images left
# Already existing file TCGA-97-A4LX-01Z-00-DX1 - 63 images left
# Already existing file TCGA-97-A4M0-01Z-00-DX1 - 62 images left
# Already existing file TCGA-97-A4M1-01Z-00-DX1 - 61 images left
# Already existing file TCGA-97-A4M2-01Z-00-DX1 - 60 images left
# Already existing file TCGA-97-A4M3-01Z-00-DX1 - 59 images left
# Already existing file TCGA-97-A4M5-01Z-00-DX1 - 58 images left
# Already existing file TCGA-97-A4M6-01Z-00-DX1 - 57 images left
# Already existing file TCGA-97-A4M7-01Z-00-DX1 - 56 images left
# Already existing file TCGA-97-A4M7-01Z-00-DX2 - 55 images left
# Already existing file TCGA-99-7458-01Z-00-DX1 - 54 images left
# Already existing file TCGA-99-8025-01Z-00-DX1 - 53 images left
# Already existing file TCGA-99-8028-01Z-00-DX1 - 52 images left
# Already existing file TCGA-99-8032-01Z-00-DX1 - 51 images left
# Already existing file TCGA-99-8033-01Z-00-DX1 - 50 images left
# Already existing file TCGA-99-AA5R-01Z-00-DX1 - 49 images left
# Already existing file TCGA-J2-8192-01Z-00-DX1 - 48 images left
# Already existing file TCGA-J2-8194-01Z-00-DX1 - 47 images left
# Already existing file TCGA-J2-A4AD-01Z-00-DX1 - 46 images left
# Already existing file TCGA-J2-A4AE-01Z-00-DX1 - 45 images left
# Already existing file TCGA-J2-A4AG-01Z-00-DX1 - 44 images left
# Already existing file TCGA-L4-A4E5-01Z-00-DX1 - 43 images left
# Already existing file TCGA-L4-A4E6-01Z-00-DX1 - 42 images left
# Already existing file TCGA-L9-A443-01Z-00-DX1 - 41 images left
# Already existing file TCGA-L9-A444-01Z-00-DX1 - 40 images left
# Already existing file TCGA-L9-A50W-01Z-00-DX1 - 39 images left
# Already existing file TCGA-L9-A5IP-01Z-00-DX1 - 38 images left
# Already existing file TCGA-L9-A743-01Z-00-DX1 - 37 images left
# Already existing file TCGA-L9-A7SV-01Z-00-DX1 - 36 images left
# Already existing file TCGA-L9-A8F4-01Z-00-DX1 - 35 images left
# Already existing file TCGA-MN-A4N1-01Z-00-DX1 - 34 images left
# Already existing file TCGA-MN-A4N1-01Z-00-DX2 - 33 images left
# Already existing file TCGA-MN-A4N4-01Z-00-DX1 - 32 images left
# Already existing file TCGA-MN-A4N4-01Z-00-DX2 - 31 images left
# Already existing file TCGA-MN-A4N5-01Z-00-DX1 - 30 images left
# Already existing file TCGA-MP-A4SV-01Z-00-DX1 - 29 images left
# Already existing file TCGA-MP-A4SW-01Z-00-DX1 - 28 images left
# Already existing file TCGA-MP-A4SY-01Z-00-DX1 - 27 images left
# Already existing file TCGA-MP-A4T2-01Z-00-DX1 - 26 images left
# Already existing file TCGA-MP-A4T4-01Z-00-DX1 - 25 images left
# Already existing file TCGA-MP-A4T6-01Z-00-DX1 - 24 images left
# Already existing file TCGA-MP-A4T7-01Z-00-DX1 - 23 images left
# Already existing file TCGA-MP-A4T8-01Z-00-DX1 - 22 images left
# Already existing file TCGA-MP-A4T9-01Z-00-DX1 - 21 images left
# Already existing file TCGA-MP-A4TA-01Z-00-DX1 - 20 images left
# Already existing file TCGA-MP-A4TC-01Z-00-DX1 - 19 images left
# Already existing file TCGA-MP-A4TD-01Z-00-DX1 - 18 images left
# Already existing file TCGA-MP-A4TE-01Z-00-DX1 - 17 images left
# Already existing file TCGA-MP-A4TF-01Z-00-DX1 - 16 images left
# Already existing file TCGA-MP-A4TH-01Z-00-DX1 - 15 images left
# Already existing file TCGA-MP-A4TI-01Z-00-DX1 - 14 images left
# Already existing file TCGA-MP-A4TJ-01Z-00-DX1 - 13 images left
# Already existing file TCGA-MP-A4TK-01Z-00-DX1 - 12 images left
# Already existing file TCGA-MP-A5C7-01Z-00-DX1 - 11 images left
# Already existing file TCGA-NJ-A4YF-01Z-00-DX1 - 10 images left
# Already existing file TCGA-NJ-A4YG-01Z-00-DX1 - 9 images left
# Already existing file TCGA-NJ-A4YI-01Z-00-DX1 - 8 images left
# Already existing file TCGA-NJ-A4YP-01Z-00-DX1 - 7 images left
# Already existing file TCGA-NJ-A4YQ-01Z-00-DX1 - 6 images left
# Already existing file TCGA-NJ-A55A-01Z-00-DX1 - 5 images left
# Already existing file TCGA-NJ-A55O-01Z-00-DX1 - 4 images left
# Already existing file TCGA-NJ-A55R-01Z-00-DX1 - 3 images left
# Already existing file TCGA-NJ-A7XG-01Z-00-DX1 - 2 images left
# Already existing file TCGA-O1-A52J-01Z-00-DX1 - 1 images left
# Already existing file TCGA-S2-AA1A-01Z-00-DX1 - 0 images left
# Finish Processing All images!

# %%
# Vectorize LUSC WSIs

vectorize_images(
    input_dir=dir_lusc_wsi,
    mask_dir=dir_lusc_wsi_mask, 
    output_dir=vectorized_lusc_dir, 
    cache_dir=cache_dir, 
    image_level=2, 
    patch_size=128
    )
# Out:
# Already existing file TCGA-18-3406-01Z-00-DX1 - 505 images left
# Already existing file TCGA-18-3407-01Z-00-DX1 - 504 images left
# Already existing file TCGA-18-3408-01Z-00-DX1 - 503 images left
# Already existing file TCGA-18-3409-01Z-00-DX1 - 502 images left
# Already existing file TCGA-18-3410-01Z-00-DX1 - 501 images left
# Already existing file TCGA-18-3411-01Z-00-DX1 - 500 images left
# Already existing file TCGA-18-3412-01Z-00-DX1 - 499 images left
# Already existing file TCGA-18-3414-01Z-00-DX1 - 498 images left
# Already existing file TCGA-18-3415-01Z-00-DX1 - 497 images left
# Already existing file TCGA-18-3416-01Z-00-DX1 - 496 images left
# Already existing file TCGA-18-3417-01Z-00-DX1 - 495 images left
# Already existing file TCGA-18-3419-01Z-00-DX1 - 494 images left
# Already existing file TCGA-18-3421-01Z-00-DX1 - 493 images left
# Already existing file TCGA-18-4083-01Z-00-DX1 - 492 images left
# Already existing file TCGA-18-4086-01Z-00-DX1 - 491 images left
# Already existing file TCGA-18-4721-01Z-00-DX1 - 490 images left
# Already existing file TCGA-18-5592-01Z-00-DX1 - 489 images left
# Already existing file TCGA-18-5595-01Z-00-DX1 - 488 images left
# Already existing file TCGA-21-1070-01Z-00-DX1 - 487 images left
# Already existing file TCGA-21-1071-01Z-00-DX1 - 486 images left
# Already existing file TCGA-21-1072-01Z-00-DX1 - 485 images left
# Already existing file TCGA-21-1075-01Z-00-DX1 - 484 images left
# Already existing file TCGA-21-1076-01Z-00-DX1 - 483 images left
# Already existing file TCGA-21-1077-01Z-00-DX1 - 482 images left
# Already existing file TCGA-21-1078-01Z-00-DX1 - 481 images left
# Already existing file TCGA-21-1079-01Z-00-DX1 - 480 images left
# Already existing file TCGA-21-1080-01Z-00-DX1 - 479 images left
# Already existing file TCGA-21-1081-01Z-00-DX1 - 478 images left
# Already existing file TCGA-21-1082-01Z-00-DX1 - 477 images left
# Already existing file TCGA-21-1083-01Z-00-DX1 - 476 images left
# Already existing file TCGA-21-5782-01Z-00-DX1 - 475 images left
# Already existing file TCGA-21-5783-01Z-00-DX1 - 474 images left
# Already existing file TCGA-21-5784-01Z-00-DX1 - 473 images left
# Already existing file TCGA-21-5786-01Z-00-DX1 - 472 images left
# Already existing file TCGA-21-5787-01Z-00-DX1 - 471 images left
# Already existing file TCGA-21-A5DI-01Z-00-DX1 - 470 images left
# Already existing file TCGA-22-0940-01Z-00-DX1 - 469 images left
# Already existing file TCGA-22-0944-01Z-00-DX1 - 468 images left
# Already existing file TCGA-22-1000-01Z-00-DX1 - 467 images left
# Already existing file TCGA-22-1002-01Z-00-DX1 - 466 images left
# Already existing file TCGA-22-1005-01Z-00-DX1 - 465 images left
# Already existing file TCGA-22-1011-01Z-00-DX1 - 464 images left
# Already existing file TCGA-22-1012-01Z-00-DX1 - 463 images left
# Already existing file TCGA-22-1016-01Z-00-DX1 - 462 images left
# Already existing file TCGA-22-1017-01Z-00-DX1 - 461 images left
# Already existing file TCGA-22-4591-01Z-00-DX1 - 460 images left
# Already existing file TCGA-22-4593-01Z-00-DX1 - 459 images left
# Already existing file TCGA-22-4594-01Z-00-DX1 - 458 images left
# Already existing file TCGA-22-4595-01Z-00-DX1 - 457 images left
# Already existing file TCGA-22-4596-01Z-00-DX1 - 456 images left
# Already existing file TCGA-22-4599-01Z-00-DX1 - 455 images left
# Already existing file TCGA-22-4601-01Z-00-DX1 - 454 images left
# Already existing file TCGA-22-4604-01Z-00-DX1 - 453 images left
# Already existing file TCGA-22-4605-01Z-00-DX1 - 452 images left
# Already existing file TCGA-22-4607-01Z-00-DX1 - 451 images left
# Already existing file TCGA-22-4609-01Z-00-DX1 - 450 images left
# Already existing file TCGA-22-4613-01Z-00-DX1 - 449 images left
# Already existing file TCGA-22-5471-01Z-00-DX1 - 448 images left
# Already existing file TCGA-22-5472-01Z-00-DX1 - 447 images left
# Already existing file TCGA-22-5473-01Z-00-DX1 - 446 images left
# Already existing file TCGA-22-5474-01Z-00-DX1 - 445 images left
# Already existing file TCGA-22-5477-01Z-00-DX1 - 444 images left
# Already existing file TCGA-22-5478-01Z-00-DX1 - 443 images left
# Already existing file TCGA-22-5479-01Z-00-DX1 - 442 images left
# Already existing file TCGA-22-5480-01Z-00-DX1 - 441 images left
# Already existing file TCGA-22-5481-01Z-00-DX1 - 440 images left
# Already existing file TCGA-22-5482-01Z-00-DX1 - 439 images left
# Already existing file TCGA-22-5483-01Z-00-DX1 - 438 images left
# Already existing file TCGA-22-5485-01Z-00-DX1 - 437 images left
# Already existing file TCGA-22-5489-01Z-00-DX1 - 436 images left
# Already existing file TCGA-22-5491-01Z-00-DX1 - 435 images left
# Already existing file TCGA-22-5492-01Z-00-DX1 - 434 images left
# Already existing file TCGA-22-A5C4-01Z-00-DX1 - 433 images left
# Already existing file TCGA-33-4532-01Z-00-DX1 - 432 images left
# Already existing file TCGA-33-4532-01Z-00-DX2 - 431 images left
# Already existing file TCGA-33-4532-01Z-00-DX3 - 430 images left
# Already existing file TCGA-33-4533-01Z-00-DX1 - 429 images left
# Already existing file TCGA-33-4533-01Z-00-DX2 - 428 images left
# Already existing file TCGA-33-4533-01Z-00-DX3 - 427 images left
# Already existing file TCGA-33-4533-01Z-00-DX4 - 426 images left
# Already existing file TCGA-33-4533-01Z-00-DX5 - 425 images left
# Already existing file TCGA-33-4538-01Z-00-DX1 - 424 images left
# Already existing file TCGA-33-4538-01Z-00-DX2 - 423 images left
# Already existing file TCGA-33-4538-01Z-00-DX3 - 422 images left
# Already existing file TCGA-33-4538-01Z-00-DX4 - 421 images left
# Already existing file TCGA-33-4538-01Z-00-DX5 - 420 images left
# Already existing file TCGA-33-4538-01Z-00-DX6 - 419 images left
# Already existing file TCGA-33-4538-01Z-00-DX7 - 418 images left
# Already existing file TCGA-33-4538-01Z-00-DX8 - 417 images left
# Already existing file TCGA-33-4538-01Z-00-DX9 - 416 images left
# Already existing file TCGA-33-4547-01Z-00-DX1 - 415 images left
# Already existing file TCGA-33-4547-01Z-00-DX2 - 414 images left
# Already existing file TCGA-33-4547-01Z-00-DX3 - 413 images left
# Already existing file TCGA-33-4547-01Z-00-DX4 - 412 images left
# Already existing file TCGA-33-4547-01Z-00-DX5 - 411 images left
# Already existing file TCGA-33-4547-01Z-00-DX6 - 410 images left
# Already existing file TCGA-33-4547-01Z-00-DX7 - 409 images left
# Already existing file TCGA-33-4566-01Z-00-DX1 - 408 images left
# Already existing file TCGA-33-4582-01Z-00-DX1 - 407 images left
# Already existing file TCGA-33-4583-01Z-00-DX1 - 406 images left
# Already existing file TCGA-33-4583-01Z-00-DX2 - 405 images left
# Already existing file TCGA-33-4583-01Z-00-DX3 - 404 images left
# Already existing file TCGA-33-4583-01Z-00-DX4 - 403 images left
# Already existing file TCGA-33-4583-01Z-00-DX5 - 402 images left
# Already existing file TCGA-33-4586-01Z-00-DX1 - 401 images left
# Already existing file TCGA-33-4586-01Z-00-DX2 - 400 images left
# Already existing file TCGA-33-4587-01Z-00-DX1 - 399 images left
# Already existing file TCGA-33-6738-01Z-00-DX1 - 398 images left
# Already existing file TCGA-33-6738-01Z-00-DX2 - 397 images left
# Already existing file TCGA-33-6738-01Z-00-DX3 - 396 images left
# Already existing file TCGA-33-6738-01Z-00-DX4 - 395 images left
# Already existing file TCGA-33-6738-01Z-00-DX5 - 394 images left
# Already existing file TCGA-33-6738-01Z-00-DX6 - 393 images left
# Already existing file TCGA-33-A4WN-01Z-00-DX1 - 392 images left
# Already existing file TCGA-33-A4WN-01Z-00-DX2 - 391 images left
# Already existing file TCGA-33-A5GW-01Z-00-DX1 - 390 images left
# Already existing file TCGA-33-A5GW-01Z-00-DX2 - 389 images left
# Already existing file TCGA-33-A5GW-01Z-00-DX3 - 388 images left
# Already existing file TCGA-33-AAS8-01Z-00-DX1 - 387 images left
# Already existing file TCGA-33-AASB-01Z-00-DX1 - 386 images left
# Already existing file TCGA-33-AASD-01Z-00-DX1 - 385 images left
# Already existing file TCGA-33-AASI-01Z-00-DX1 - 384 images left
# Already existing file TCGA-33-AASJ-01Z-00-DX1 - 383 images left
# Already existing file TCGA-33-AASL-01Z-00-DX1 - 382 images left
# Already existing file TCGA-34-2596-01Z-00-DX1 - 381 images left
# Already existing file TCGA-34-2600-01Z-00-DX1 - 380 images left
# Already existing file TCGA-34-5232-01Z-00-DX1 - 379 images left
# Already existing file TCGA-34-5240-01Z-00-DX1 - 378 images left
# Already existing file TCGA-34-5241-01Z-00-DX1 - 377 images left
# Already existing file TCGA-34-5928-01Z-00-DX1 - 376 images left
# Already existing file TCGA-34-5929-01Z-00-DX1 - 375 images left
# Already existing file TCGA-34-7107-01Z-00-DX1 - 374 images left
# Already existing file TCGA-34-8454-01Z-00-DX1 - 373 images left
# Already existing file TCGA-34-8455-01Z-00-DX1 - 372 images left
# Already existing file TCGA-34-A5IX-01Z-00-DX1 - 371 images left
# Already existing file TCGA-37-3783-01Z-00-DX1 - 370 images left
# Already existing file TCGA-37-3789-01Z-00-DX1 - 369 images left
# Already existing file TCGA-37-3792-01Z-00-DX1 - 368 images left
# Already existing file TCGA-37-4129-01Z-00-DX1 - 367 images left
# Already existing file TCGA-37-4130-01Z-00-DX1 - 366 images left
# Already existing file TCGA-37-4132-01Z-00-DX1 - 365 images left
# Already existing file TCGA-37-4133-01Z-00-DX1 - 364 images left
# Already existing file TCGA-37-4135-01Z-00-DX1 - 363 images left
# Already existing file TCGA-37-4141-01Z-00-DX1 - 362 images left
# Already existing file TCGA-37-5819-01Z-00-DX1 - 361 images left
# Already existing file TCGA-37-A5EL-01Z-00-DX1 - 360 images left
# Already existing file TCGA-37-A5EM-01Z-00-DX1 - 359 images left
# Already existing file TCGA-37-A5EN-01Z-00-DX1 - 358 images left
# Already existing file TCGA-39-5011-01Z-00-DX1 - 357 images left
# Already existing file TCGA-39-5016-01Z-00-DX1 - 356 images left
# Already existing file TCGA-39-5019-01Z-00-DX1 - 355 images left
# Already existing file TCGA-39-5021-01Z-00-DX1 - 354 images left
# Already existing file TCGA-39-5022-01Z-00-DX1 - 353 images left
# Already existing file TCGA-39-5024-01Z-00-DX1 - 352 images left
# Already existing file TCGA-39-5027-01Z-00-DX1 - 351 images left
# Already existing file TCGA-39-5028-01Z-00-DX1 - 350 images left
# Already existing file TCGA-39-5029-01Z-00-DX1 - 349 images left
# Already existing file TCGA-39-5030-01Z-00-DX1 - 348 images left
# Already existing file TCGA-39-5031-01Z-00-DX1 - 347 images left
# Already existing file TCGA-39-5034-01Z-00-DX1 - 346 images left
# Already existing file TCGA-39-5035-01Z-00-DX1 - 345 images left
# Already existing file TCGA-39-5036-01Z-00-DX1 - 344 images left
# Already existing file TCGA-39-5037-01Z-00-DX1 - 343 images left
# Already existing file TCGA-39-5039-01Z-00-DX1 - 342 images left
# Already existing file TCGA-39-5040-01Z-00-DX1 - 341 images left
# Already existing file TCGA-43-2576-01Z-00-DX1 - 340 images left
# Already existing file TCGA-43-2578-01Z-00-DX1 - 339 images left
# Already existing file TCGA-43-2581-01Z-00-DX1 - 338 images left
# Already existing file TCGA-43-3394-01Z-00-DX1 - 337 images left
# Already existing file TCGA-43-3920-01Z-00-DX1 - 336 images left
# Already existing file TCGA-43-5668-01Z-00-DX1 - 335 images left
# Already existing file TCGA-43-5670-01Z-00-DX1 - 334 images left
# Already existing file TCGA-43-6143-01Z-00-DX1 - 333 images left
# Already existing file TCGA-43-6647-01Z-00-DX1 - 332 images left
# Already existing file TCGA-43-6770-01Z-00-DX1 - 331 images left
# Already existing file TCGA-43-6771-01Z-00-DX1 - 330 images left
# Already existing file TCGA-43-6773-01Z-00-DX1 - 329 images left
# Already existing file TCGA-43-7656-01Z-00-DX1 - 328 images left
# Already existing file TCGA-43-7657-01Z-00-DX1 - 327 images left
# Already existing file TCGA-43-7658-01Z-00-DX1 - 326 images left
# Already existing file TCGA-43-8115-01Z-00-DX1 - 325 images left
# Already existing file TCGA-43-A474-01Z-00-DX1 - 324 images left
# Already existing file TCGA-43-A475-01Z-00-DX1 - 323 images left
# Already existing file TCGA-43-A56U-01Z-00-DX1 - 322 images left
# Already existing file TCGA-43-A56V-01Z-00-DX1 - 321 images left
# Already existing file TCGA-46-3765-01Z-00-DX1 - 320 images left
# Already existing file TCGA-46-3766-01Z-00-DX1 - 319 images left
# Already existing file TCGA-46-3767-01Z-00-DX1 - 318 images left
# Already existing file TCGA-46-3768-01Z-00-DX1 - 317 images left
# Already existing file TCGA-46-3769-01Z-00-DX1 - 316 images left
# Already existing file TCGA-46-6025-01Z-00-DX1 - 315 images left
# Already existing file TCGA-46-6026-01Z-00-DX1 - 314 images left
# Already existing file TCGA-51-4079-01Z-00-DX1 - 313 images left
# Already existing file TCGA-51-4080-01Z-00-DX1 - 312 images left
# Already existing file TCGA-51-4081-01Z-00-DX1 - 311 images left
# Already existing file TCGA-51-6867-01Z-00-DX1 - 310 images left
# Already existing file TCGA-52-7622-01Z-00-DX1 - 309 images left
# Already existing file TCGA-52-7809-01Z-00-DX1 - 308 images left
# Already existing file TCGA-52-7810-01Z-00-DX1 - 307 images left
# Already existing file TCGA-52-7811-01Z-00-DX1 - 306 images left
# Already existing file TCGA-52-7812-01Z-00-DX1 - 305 images left
# Already existing file TCGA-56-1622-01Z-00-DX1 - 304 images left
# Already existing file TCGA-56-5897-01Z-00-DX1 - 303 images left
# Already existing file TCGA-56-5898-01Z-00-DX1 - 302 images left
# Already existing file TCGA-56-6545-01Z-00-DX1 - 301 images left
# Already existing file TCGA-56-7221-01Z-00-DX1 - 300 images left
# Already existing file TCGA-56-7222-01Z-00-DX1 - 299 images left
# Already existing file TCGA-56-7223-01Z-00-DX1 - 298 images left
# Already existing file TCGA-56-7579-01Z-00-DX1 - 297 images left
# Already existing file TCGA-56-7580-01Z-00-DX1 - 296 images left
# Already existing file TCGA-56-7582-01Z-00-DX1 - 295 images left
# Already existing file TCGA-56-7730-01Z-00-DX1 - 294 images left
# Already existing file TCGA-56-7731-01Z-00-DX1 - 293 images left
# Already existing file TCGA-56-7822-01Z-00-DX1 - 292 images left
# Already existing file TCGA-56-7823-01Z-00-DX1 - 291 images left
# Already existing file TCGA-56-8082-01Z-00-DX1 - 290 images left
# Already existing file TCGA-56-8083-01Z-00-DX1 - 289 images left
# Already existing file TCGA-56-8201-01Z-00-DX1 - 288 images left
# Already existing file TCGA-56-8304-01Z-00-DX1 - 287 images left
# Already existing file TCGA-56-8305-01Z-00-DX1 - 286 images left
# Already existing file TCGA-56-8307-01Z-00-DX1 - 285 images left
# Already existing file TCGA-56-8308-01Z-00-DX1 - 284 images left
# Already existing file TCGA-56-8309-01Z-00-DX1 - 283 images left
# Already existing file TCGA-56-8503-01Z-00-DX1 - 282 images left
# Already existing file TCGA-56-8504-01Z-00-DX1 - 281 images left
# Already existing file TCGA-56-8622-01Z-00-DX1 - 280 images left
# Already existing file TCGA-56-8623-01Z-00-DX1 - 279 images left
# Already existing file TCGA-56-8624-01Z-00-DX1 - 278 images left
# Already existing file TCGA-56-8625-01Z-00-DX1 - 277 images left
# Already existing file TCGA-56-8626-01Z-00-DX1 - 276 images left
# Already existing file TCGA-56-8628-01Z-00-DX1 - 275 images left
# Already existing file TCGA-56-8629-01Z-00-DX1 - 274 images left
# Already existing file TCGA-56-A49D-01Z-00-DX1 - 273 images left
# Already existing file TCGA-56-A4BW-01Z-00-DX1 - 272 images left
# Already existing file TCGA-56-A4BX-01Z-00-DX1 - 271 images left
# Already existing file TCGA-56-A4BY-01Z-00-DX1 - 270 images left
# Already existing file TCGA-56-A4ZJ-01Z-00-DX1 - 269 images left
# Already existing file TCGA-56-A4ZK-01Z-00-DX1 - 268 images left
# Already existing file TCGA-56-A5DR-01Z-00-DX1 - 267 images left
# Already existing file TCGA-56-A5DS-01Z-00-DX1 - 266 images left
# Already existing file TCGA-56-A62T-01Z-00-DX1 - 265 images left
# Already existing file TCGA-58-A46J-01Z-00-DX1 - 264 images left
# Already existing file TCGA-58-A46K-01Z-00-DX1 - 263 images left
# Already existing file TCGA-58-A46L-01Z-00-DX1 - 262 images left
# Already existing file TCGA-58-A46M-01Z-00-DX1 - 261 images left
# Already existing file TCGA-58-A46N-01Z-00-DX1 - 260 images left
# Already existing file TCGA-60-2695-01Z-00-DX1 - 259 images left
# Already existing file TCGA-60-2696-01Z-00-DX1 - 258 images left
# Already existing file TCGA-60-2697-01Z-00-DX1 - 257 images left
# Already existing file TCGA-60-2698-01Z-00-DX1 - 256 images left
# Already existing file TCGA-60-2703-01Z-00-DX1 - 255 images left
# Already existing file TCGA-60-2704-01Z-00-DX1 - 254 images left
# Already existing file TCGA-60-2706-01Z-00-DX1 - 253 images left
# Already existing file TCGA-60-2707-01Z-00-DX1 - 252 images left
# Already existing file TCGA-60-2708-01Z-00-DX1 - 251 images left
# Already existing file TCGA-60-2709-01Z-00-DX1 - 250 images left
# Already existing file TCGA-60-2710-01Z-00-DX1 - 249 images left
# Already existing file TCGA-60-2711-01Z-00-DX1 - 248 images left
# Already existing file TCGA-60-2712-01Z-00-DX1 - 247 images left
# Already existing file TCGA-60-2713-01Z-00-DX1 - 246 images left
# Already existing file TCGA-60-2714-01Z-00-DX1 - 245 images left
# Already existing file TCGA-60-2715-01Z-00-DX1 - 244 images left
# Already existing file TCGA-60-2716-01Z-00-DX1 - 243 images left
# Already existing file TCGA-60-2719-01Z-00-DX1 - 242 images left
# Already existing file TCGA-60-2720-01Z-00-DX1 - 241 images left
# Already existing file TCGA-60-2721-01Z-00-DX1 - 240 images left
# Already existing file TCGA-60-2722-01Z-00-DX1 - 239 images left
# Already existing file TCGA-60-2723-01Z-00-DX1 - 238 images left
# Already existing file TCGA-60-2724-01Z-00-DX1 - 237 images left
# Already existing file TCGA-60-2725-01Z-00-DX1 - 236 images left
# Already existing file TCGA-60-2726-01Z-00-DX1 - 235 images left
# Already existing file TCGA-63-6202-01Z-00-DX1 - 234 images left
# Already existing file TCGA-63-7020-01Z-00-DX1 - 233 images left
# Already existing file TCGA-63-7021-01Z-00-DX1 - 232 images left
# Already existing file TCGA-63-7022-01Z-00-DX1 - 231 images left
# Already existing file TCGA-63-7023-01Z-00-DX1 - 230 images left
# Already existing file TCGA-63-A5M9-01Z-00-DX1 - 229 images left
# Already existing file TCGA-63-A5MB-01Z-00-DX1 - 228 images left
# Already existing file TCGA-63-A5MG-01Z-00-DX1 - 227 images left
# Already existing file TCGA-63-A5MH-01Z-00-DX1 - 226 images left
# Already existing file TCGA-63-A5MI-01Z-00-DX1 - 225 images left
# Already existing file TCGA-63-A5MJ-01Z-00-DX1 - 224 images left
# Already existing file TCGA-63-A5ML-01Z-00-DX1 - 223 images left
# Already existing file TCGA-63-A5MM-01Z-00-DX1 - 222 images left
# Already existing file TCGA-63-A5MN-01Z-00-DX1 - 221 images left
# Already existing file TCGA-63-A5MP-01Z-00-DX1 - 220 images left
# Already existing file TCGA-63-A5MR-01Z-00-DX1 - 219 images left
# Already existing file TCGA-63-A5MS-01Z-00-DX1 - 218 images left
# Already existing file TCGA-63-A5MT-01Z-00-DX1 - 217 images left
# Already existing file TCGA-63-A5MU-01Z-00-DX1 - 216 images left
# Already existing file TCGA-63-A5MV-01Z-00-DX1 - 215 images left
# Already existing file TCGA-63-A5MW-01Z-00-DX1 - 214 images left
# Already existing file TCGA-63-A5MY-01Z-00-DX1 - 213 images left
# Already existing file TCGA-66-2727-01Z-00-DX1 - 212 images left
# Already existing file TCGA-66-2734-01Z-00-DX1 - 211 images left
# Already existing file TCGA-66-2737-01Z-00-DX1 - 210 images left
# Already existing file TCGA-66-2742-01Z-00-DX1 - 209 images left
# Already existing file TCGA-66-2744-01Z-00-DX1 - 208 images left
# Already existing file TCGA-66-2753-01Z-00-DX1 - 207 images left
# Already existing file TCGA-66-2754-01Z-00-DX1 - 206 images left
# Already existing file TCGA-66-2755-01Z-00-DX1 - 205 images left
# Already existing file TCGA-66-2756-01Z-00-DX1 - 204 images left
# Already existing file TCGA-66-2757-01Z-00-DX1 - 203 images left
# Already existing file TCGA-66-2758-01Z-00-DX1 - 202 images left
# Already existing file TCGA-66-2759-01Z-00-DX1 - 201 images left
# Already existing file TCGA-66-2763-01Z-00-DX1 - 200 images left
# Already existing file TCGA-66-2765-01Z-00-DX1 - 199 images left
# Already existing file TCGA-66-2766-01Z-00-DX1 - 198 images left
# Already existing file TCGA-66-2767-01Z-00-DX1 - 197 images left
# Already existing file TCGA-66-2768-01Z-00-DX1 - 196 images left
# Already existing file TCGA-66-2769-01Z-00-DX1 - 195 images left
# Already existing file TCGA-66-2770-01Z-00-DX1 - 194 images left
# Already existing file TCGA-66-2770-01Z-00-DX2 - 193 images left
# Already existing file TCGA-66-2771-01Z-00-DX1 - 192 images left
# Already existing file TCGA-66-2773-01Z-00-DX1 - 191 images left
# Already existing file TCGA-66-2777-01Z-00-DX1 - 190 images left
# Already existing file TCGA-66-2778-01Z-00-DX1 - 189 images left
# Already existing file TCGA-66-2780-01Z-00-DX1 - 188 images left
# Already existing file TCGA-66-2781-01Z-00-DX1 - 187 images left
# Already existing file TCGA-66-2783-01Z-00-DX1 - 186 images left
# Already existing file TCGA-66-2785-01Z-00-DX1 - 185 images left
# Already existing file TCGA-66-2786-01Z-00-DX1 - 184 images left
# Already existing file TCGA-66-2787-01Z-00-DX1 - 183 images left
# Already existing file TCGA-66-2788-01Z-00-DX1 - 182 images left
# Already existing file TCGA-66-2789-01Z-00-DX1 - 181 images left
# Already existing file TCGA-66-2790-01Z-00-DX1 - 180 images left
# Already existing file TCGA-66-2791-01Z-00-DX1 - 179 images left
# Already existing file TCGA-66-2792-01Z-00-DX1 - 178 images left
# Already existing file TCGA-66-2793-01Z-00-DX1 - 177 images left
# Already existing file TCGA-66-2794-01Z-00-DX1 - 176 images left
# Already existing file TCGA-66-2795-01Z-00-DX1 - 175 images left
# Already existing file TCGA-66-2800-01Z-00-DX1 - 174 images left
# Already existing file TCGA-68-7755-01Z-00-DX1 - 173 images left
# Already existing file TCGA-68-7756-01Z-00-DX1 - 172 images left
# Already existing file TCGA-68-7757-01Z-00-DX1 - 171 images left
# Already existing file TCGA-68-8250-01Z-00-DX1 - 170 images left
# Already existing file TCGA-68-8251-01Z-00-DX1 - 169 images left
# Already existing file TCGA-68-A59I-01Z-00-DX1 - 168 images left
# Already existing file TCGA-68-A59J-01Z-00-DX1 - 167 images left
# Already existing file TCGA-70-6722-01Z-00-DX1 - 166 images left
# Already existing file TCGA-70-6723-01Z-00-DX1 - 165 images left
# Already existing file TCGA-77-6842-01Z-00-DX1 - 164 images left
# Already existing file TCGA-77-6843-01Z-00-DX1 - 163 images left
# Already existing file TCGA-77-6844-01Z-00-DX1 - 162 images left
# Already existing file TCGA-77-6845-01Z-00-DX1 - 161 images left
# Already existing file TCGA-77-7138-01Z-00-DX1 - 160 images left
# Already existing file TCGA-77-7139-01Z-00-DX1 - 159 images left
# Already existing file TCGA-77-7140-01Z-00-DX1 - 158 images left
# Already existing file TCGA-77-7141-01Z-00-DX1 - 157 images left
# Already existing file TCGA-77-7142-01Z-00-DX1 - 156 images left
# Already existing file TCGA-77-7335-01Z-00-DX1 - 155 images left
# Already existing file TCGA-77-7337-01Z-00-DX1 - 154 images left
# Already existing file TCGA-77-7338-01Z-00-DX1 - 153 images left
# Already existing file TCGA-77-7463-01Z-00-DX1 - 152 images left
# Already existing file TCGA-77-7465-01Z-00-DX1 - 151 images left
# Already existing file TCGA-77-8007-01Z-00-DX1 - 150 images left
# Already existing file TCGA-77-8008-01Z-00-DX1 - 149 images left
# Already existing file TCGA-77-8009-01Z-00-DX1 - 148 images left
# Already existing file TCGA-77-8128-01Z-00-DX1 - 147 images left
# Already existing file TCGA-77-8130-01Z-00-DX1 - 146 images left
# Already existing file TCGA-77-8131-01Z-00-DX1 - 145 images left
# Already existing file TCGA-77-8133-01Z-00-DX1 - 144 images left
# Already existing file TCGA-77-8136-01Z-00-DX1 - 143 images left
# Already existing file TCGA-77-8138-01Z-00-DX1 - 142 images left
# Already existing file TCGA-77-8139-01Z-00-DX1 - 141 images left
# Already existing file TCGA-77-8140-01Z-00-DX1 - 140 images left
# Already existing file TCGA-77-8143-01Z-00-DX1 - 139 images left
# Already existing file TCGA-77-8144-01Z-00-DX1 - 138 images left
# Already existing file TCGA-77-8145-01Z-00-DX1 - 137 images left
# Already existing file TCGA-77-8146-01Z-00-DX1 - 136 images left
# Already existing file TCGA-77-8148-01Z-00-DX1 - 135 images left
# Already existing file TCGA-77-8150-01Z-00-DX1 - 134 images left
# Already existing file TCGA-77-8153-01Z-00-DX1 - 133 images left
# Already existing file TCGA-77-8154-01Z-00-DX1 - 132 images left
# Already existing file TCGA-77-8156-01Z-00-DX1 - 131 images left
# Already existing file TCGA-77-A5FZ-01Z-00-DX1 - 130 images left
# Already existing file TCGA-77-A5G1-01Z-00-DX1 - 129 images left
# Already existing file TCGA-77-A5G3-01Z-00-DX1 - 128 images left
# Already existing file TCGA-77-A5G6-01Z-00-DX1 - 127 images left
# Already existing file TCGA-77-A5G7-01Z-00-DX1 - 126 images left
# Already existing file TCGA-77-A5G8-01Z-00-DX1 - 125 images left
# Already existing file TCGA-77-A5GA-01Z-00-DX1 - 124 images left
# Already existing file TCGA-77-A5GB-01Z-00-DX1 - 123 images left
# Already existing file TCGA-77-A5GF-01Z-00-DX1 - 122 images left
# Already existing file TCGA-77-A5GH-01Z-00-DX1 - 121 images left
# Already existing file TCGA-85-6175-01Z-00-DX1 - 120 images left
# Already existing file TCGA-85-6560-01Z-00-DX1 - 119 images left
# Already existing file TCGA-85-6561-01Z-00-DX1 - 118 images left
# Already existing file TCGA-85-6798-01Z-00-DX1 - 117 images left
# Already existing file TCGA-85-7696-01Z-00-DX1 - 116 images left
# Already existing file TCGA-85-7697-01Z-00-DX1 - 115 images left
# Already existing file TCGA-85-7698-01Z-00-DX1 - 114 images left
# Already existing file TCGA-85-7699-01Z-00-DX1 - 113 images left
# Already existing file TCGA-85-7710-01Z-00-DX1 - 112 images left
# Already existing file TCGA-85-7843-01Z-00-DX1 - 111 images left
# Already existing file TCGA-85-7844-01Z-00-DX1 - 110 images left
# Already existing file TCGA-85-7950-01Z-00-DX1 - 109 images left
# Already existing file TCGA-85-8048-01Z-00-DX1 - 108 images left
# Already existing file TCGA-85-8049-01Z-00-DX1 - 107 images left
# Already existing file TCGA-85-8052-01Z-00-DX1 - 106 images left
# Already existing file TCGA-85-8070-01Z-00-DX1 - 105 images left
# Already existing file TCGA-85-8071-01Z-00-DX1 - 104 images left
# Already existing file TCGA-85-8072-01Z-00-DX1 - 103 images left
# Already existing file TCGA-85-8276-01Z-00-DX1 - 102 images left
# Already existing file TCGA-85-8277-01Z-00-DX1 - 101 images left
# Already existing file TCGA-85-8287-01Z-00-DX1 - 100 images left
# Already existing file TCGA-85-8288-01Z-00-DX1 - 99 images left
# Already existing file TCGA-85-8350-01Z-00-DX1 - 98 images left
# Already existing file TCGA-85-8351-01Z-00-DX1 - 97 images left
# Already existing file TCGA-85-8352-01Z-00-DX1 - 96 images left
# Already existing file TCGA-85-8353-01Z-00-DX1 - 95 images left
# Already existing file TCGA-85-8354-01Z-00-DX1 - 94 images left
# Already existing file TCGA-85-8355-01Z-00-DX1 - 93 images left
# Already existing file TCGA-85-8479-01Z-00-DX1 - 92 images left
# Already existing file TCGA-85-8481-01Z-00-DX1 - 91 images left
# Already existing file TCGA-85-8580-01Z-00-DX1 - 90 images left
# Already existing file TCGA-85-8582-01Z-00-DX1 - 89 images left
# Already existing file TCGA-85-8584-01Z-00-DX1 - 88 images left
# Already existing file TCGA-85-8664-01Z-00-DX1 - 87 images left
# Already existing file TCGA-85-8666-01Z-00-DX1 - 86 images left
# Already existing file TCGA-85-A4CL-01Z-00-DX1 - 85 images left
# Already existing file TCGA-85-A4CN-01Z-00-DX1 - 84 images left
# Already existing file TCGA-85-A4JB-01Z-00-DX1 - 83 images left
# Already existing file TCGA-85-A4JC-01Z-00-DX1 - 82 images left
# Already existing file TCGA-85-A4PA-01Z-00-DX1 - 81 images left
# Already existing file TCGA-85-A4QQ-01Z-00-DX1 - 80 images left
# Already existing file TCGA-85-A4QR-01Z-00-DX1 - 79 images left
# Already existing file TCGA-85-A50M-01Z-00-DX1 - 78 images left
# Already existing file TCGA-85-A50Z-01Z-00-DX1 - 77 images left
# Already existing file TCGA-85-A510-01Z-00-DX1 - 76 images left
# Already existing file TCGA-85-A511-01Z-00-DX1 - 75 images left
# Already existing file TCGA-85-A512-01Z-00-DX1 - 74 images left
# Already existing file TCGA-85-A513-01Z-00-DX1 - 73 images left
# Already existing file TCGA-85-A53L-01Z-00-DX1 - 72 images left
# Already existing file TCGA-85-A5B5-01Z-00-DX1 - 71 images left
# Already existing file TCGA-90-7964-01Z-00-DX1 - 70 images left
# Already existing file TCGA-90-A4ED-01Z-00-DX1 - 69 images left
# Already existing file TCGA-90-A4EE-01Z-00-DX1 - 68 images left
# Already existing file TCGA-90-A59Q-01Z-00-DX1 - 67 images left
# Already existing file TCGA-92-7340-01Z-00-DX1 - 66 images left
# Already existing file TCGA-92-7341-01Z-00-DX1 - 65 images left
# Already existing file TCGA-92-8063-01Z-00-DX1 - 64 images left
# Already existing file TCGA-92-8064-01Z-00-DX1 - 63 images left
# Already existing file TCGA-92-8065-01Z-00-DX1 - 62 images left
# Already existing file TCGA-94-7033-01Z-00-DX1 - 61 images left
# Already existing file TCGA-94-7557-01Z-00-DX1 - 60 images left
# Already existing file TCGA-94-7943-01Z-00-DX1 - 59 images left
# Already existing file TCGA-94-8035-01Z-00-DX1 - 58 images left
# Already existing file TCGA-94-8490-01Z-00-DX1 - 57 images left
# Already existing file TCGA-94-8491-01Z-00-DX1 - 56 images left
# Already existing file TCGA-94-A4VJ-01Z-00-DX1 - 55 images left
# Already existing file TCGA-94-A5I4-01Z-00-DX1 - 54 images left
# Already existing file TCGA-94-A5I6-01Z-00-DX1 - 53 images left
# Already existing file TCGA-96-7544-01Z-00-DX1 - 52 images left
# Already existing file TCGA-96-7545-01Z-00-DX1 - 51 images left
# Already existing file TCGA-96-8169-01Z-00-DX1 - 50 images left
# Already existing file TCGA-96-8170-01Z-00-DX1 - 49 images left
# Already existing file TCGA-96-A4JK-01Z-00-DX1 - 48 images left
# Already existing file TCGA-96-A4JL-01Z-00-DX1 - 47 images left
# Already existing file TCGA-98-7454-01Z-00-DX1 - 46 images left
# Already existing file TCGA-98-8020-01Z-00-DX1 - 45 images left
# Already existing file TCGA-98-8021-01Z-00-DX1 - 44 images left
# Already existing file TCGA-98-8022-01Z-00-DX1 - 43 images left
# Already existing file TCGA-98-8023-01Z-00-DX1 - 42 images left
# Already existing file TCGA-98-A538-01Z-00-DX1 - 41 images left
# Already existing file TCGA-98-A539-01Z-00-DX1 - 40 images left
# Already existing file TCGA-98-A53A-01Z-00-DX1 - 39 images left
# Already existing file TCGA-98-A53B-01Z-00-DX1 - 38 images left
# Already existing file TCGA-98-A53C-01Z-00-DX1 - 37 images left
# Already existing file TCGA-98-A53D-01Z-00-DX1 - 36 images left
# Already existing file TCGA-98-A53H-01Z-00-DX1 - 35 images left
# Already existing file TCGA-98-A53I-01Z-00-DX1 - 34 images left
# Already existing file TCGA-98-A53J-01Z-00-DX1 - 33 images left
# Already existing file TCGA-J1-A4AH-01Z-00-DX1 - 32 images left
# Already existing file TCGA-L3-A4E7-01Z-00-DX1 - 31 images left
# Already existing file TCGA-L3-A524-01Z-00-DX1 - 30 images left
# Already existing file TCGA-LA-A446-01Z-00-DX1 - 29 images left
# Already existing file TCGA-LA-A7SW-01Z-00-DX1 - 28 images left
# Already existing file TCGA-MF-A522-01Z-00-DX1 - 27 images left
# Already existing file TCGA-NC-A5HD-01Z-00-DX1 - 26 images left
# Already existing file TCGA-NC-A5HE-01Z-00-DX1 - 25 images left
# Already existing file TCGA-NC-A5HF-01Z-00-DX1 - 24 images left
# Already existing file TCGA-NC-A5HG-01Z-00-DX1 - 23 images left
# Already existing file TCGA-NC-A5HH-01Z-00-DX1 - 22 images left
# Already existing file TCGA-NC-A5HI-01Z-00-DX1 - 21 images left
# Already existing file TCGA-NC-A5HJ-01Z-00-DX1 - 20 images left
# Already existing file TCGA-NC-A5HK-01Z-00-DX1 - 19 images left
# Already existing file TCGA-NC-A5HL-01Z-00-DX1 - 18 images left
# Already existing file TCGA-NC-A5HM-01Z-00-DX1 - 17 images left
# Already existing file TCGA-NC-A5HN-01Z-00-DX1 - 16 images left
# Already existing file TCGA-NC-A5HO-01Z-00-DX1 - 15 images left
# Already existing file TCGA-NC-A5HP-01Z-00-DX1 - 14 images left
# Already existing file TCGA-NC-A5HQ-01Z-00-DX1 - 13 images left
# Already existing file TCGA-NC-A5HR-01Z-00-DX1 - 12 images left
# Already existing file TCGA-NC-A5HT-01Z-00-DX1 - 11 images left
# Already existing file TCGA-NK-A5CR-01Z-00-DX1 - 10 images left
# Already existing file TCGA-NK-A5CT-01Z-00-DX1 - 9 images left
# Already existing file TCGA-NK-A5CX-01Z-00-DX1 - 8 images left
# Already existing file TCGA-NK-A5D1-01Z-00-DX1 - 7 images left
# Already existing file TCGA-NK-A7XE-01Z-00-DX1 - 6 images left
# Already existing file TCGA-O2-A52N-01Z-00-DX1 - 5 images left
# Already existing file TCGA-O2-A52S-01Z-00-DX1 - 4 images left
# Already existing file TCGA-O2-A52V-01Z-00-DX1 - 3 images left
# Already existing file TCGA-O2-A52W-01Z-00-DX1 - 2 images left
# Already existing file TCGA-O2-A5IB-01Z-00-DX1 - 1 images left
# Already existing file TCGA-XC-AA0X-01Z-00-DX1 - 0 images left
# Finish Processing All images!

# %% [markdown]
# Now we can compress the WSIs. Each WSI (vectorized file) will be processed 8 times due to WSI-level augmentation (rotation and flip). We will use an existing pretrained encoder from the NIC paper.

# %%
# Featurize images
from featurize_wsi import featurize_images

# Featurize LUAD data
featurize_images(
    input_dir=vectorized_luad_dir,
    model_path=model_path, 
    output_dir=featurized_luad_dir, 
    batch_size=32
    )
# Out:
# Already existing file TCGA-05-4244-01Z-00-DX1_{item} - 530 images left
# Already existing file TCGA-05-4245-01Z-00-DX1_{item} - 529 images left
# Already existing file TCGA-05-4249-01Z-00-DX1_{item} - 528 images left
# Already existing file TCGA-05-4250-01Z-00-DX1_{item} - 527 images left
# Already existing file TCGA-05-4382-01Z-00-DX1_{item} - 526 images left
# Already existing file TCGA-05-4395-01Z-00-DX1_{item} - 525 images left
# Already existing file TCGA-05-4396-01Z-00-DX1_{item} - 524 images left
# Already existing file TCGA-05-4397-01Z-00-DX1_{item} - 523 images left
# Already existing file TCGA-05-4398-01Z-00-DX1_{item} - 522 images left
# Already existing file TCGA-05-4402-01Z-00-DX1_{item} - 521 images left
# Already existing file TCGA-05-4403-01Z-00-DX1_{item} - 520 images left
# Already existing file TCGA-05-4405-01Z-00-DX1_{item} - 519 images left
# Already existing file TCGA-05-4415-01Z-00-DX1_{item} - 518 images left
# Already existing file TCGA-05-4417-01Z-00-DX1_{item} - 517 images left
# Already existing file TCGA-05-4418-01Z-00-DX1_{item} - 516 images left
# Already existing file TCGA-05-4420-01Z-00-DX1_{item} - 515 images left
# Already existing file TCGA-05-4422-01Z-00-DX1_{item} - 514 images left
# Already existing file TCGA-05-4424-01Z-00-DX1_{item} - 513 images left
# Already existing file TCGA-05-4426-01Z-00-DX1_{item} - 512 images left
# Already existing file TCGA-05-4427-01Z-00-DX1_{item} - 511 images left
# Already existing file TCGA-05-4430-01Z-00-DX1_{item} - 510 images left
# Already existing file TCGA-05-4432-01Z-00-DX1_{item} - 509 images left
# Already existing file TCGA-05-4433-01Z-00-DX1_{item} - 508 images left
# Already existing file TCGA-05-4434-01Z-00-DX1_{item} - 507 images left
# Already existing file TCGA-35-3615-01Z-00-DX1_{item} - 506 images left
# Already existing file TCGA-35-4122-01Z-00-DX1_{item} - 505 images left
# Already existing file TCGA-35-4123-01Z-00-DX1_{item} - 504 images left
# Already existing file TCGA-35-5375-01Z-00-DX1_{item} - 503 images left
# Already existing file TCGA-38-4625-01Z-00-DX1_{item} - 502 images left
# Already existing file TCGA-38-4626-01Z-00-DX1_{item} - 501 images left
# Already existing file TCGA-38-4627-01Z-00-DX1_{item} - 500 images left
# Already existing file TCGA-38-4628-01Z-00-DX1_{item} - 499 images left
# Already existing file TCGA-38-4629-01Z-00-DX1_{item} - 498 images left
# Already existing file TCGA-38-4630-01Z-00-DX1_{item} - 497 images left
# Already existing file TCGA-38-4631-01Z-00-DX1_{item} - 496 images left
# Already existing file TCGA-38-4632-01Z-00-DX1_{item} - 495 images left
# Already existing file TCGA-38-6178-01Z-00-DX1_{item} - 494 images left
# Already existing file TCGA-38-7271-01Z-00-DX1_{item} - 493 images left
# Already existing file TCGA-38-A44F-01Z-00-DX1_{item} - 492 images left
# Already existing file TCGA-44-2655-01Z-00-DX1_{item} - 491 images left
# Already existing file TCGA-44-2656-01Z-00-DX1_{item} - 490 images left
# Already existing file TCGA-44-2657-01Z-00-DX1_{item} - 489 images left
# Already existing file TCGA-44-2659-01Z-00-DX1_{item} - 488 images left
# Already existing file TCGA-44-2661-01Z-00-DX1_{item} - 487 images left
# Already existing file TCGA-44-2662-01Z-00-DX1_{item} - 486 images left
# Already existing file TCGA-44-2664-01Z-00-DX1_{item} - 485 images left
# Already existing file TCGA-44-2665-01Z-00-DX1_{item} - 484 images left
# Already existing file TCGA-44-2666-01Z-00-DX1_{item} - 483 images left
# Already existing file TCGA-44-2668-01Z-00-DX1_{item} - 482 images left
# Already existing file TCGA-44-3396-01Z-00-DX1_{item} - 481 images left
# Already existing file TCGA-44-3398-01Z-00-DX1_{item} - 480 images left
# Already existing file TCGA-44-3917-01Z-00-DX1_{item} - 479 images left
# Already existing file TCGA-44-3918-01Z-00-DX1_{item} - 478 images left
# Already existing file TCGA-44-3919-01Z-00-DX1_{item} - 477 images left
# Already existing file TCGA-44-4112-01Z-00-DX1_{item} - 476 images left
# Already existing file TCGA-44-5643-01Z-00-DX1_{item} - 475 images left
# Already existing file TCGA-44-5644-01Z-00-DX1_{item} - 474 images left
# Already existing file TCGA-44-5645-01Z-00-DX1_{item} - 473 images left
# Already existing file TCGA-44-6144-01Z-00-DX1_{item} - 472 images left
# Already existing file TCGA-44-6145-01Z-00-DX1_{item} - 471 images left
# Already existing file TCGA-44-6146-01Z-00-DX1_{item} - 470 images left
# Already existing file TCGA-44-6147-01Z-00-DX1_{item} - 469 images left
# Already existing file TCGA-44-6148-01Z-00-DX1_{item} - 468 images left
# Already existing file TCGA-44-6774-01Z-00-DX1_{item} - 467 images left
# Already existing file TCGA-44-6775-01Z-00-DX1_{item} - 466 images left
# Already existing file TCGA-44-6776-01Z-00-DX1_{item} - 465 images left
# Already existing file TCGA-44-6777-01Z-00-DX1_{item} - 464 images left
# Already existing file TCGA-44-6778-01Z-00-DX1_{item} - 463 images left
# Already existing file TCGA-44-6779-01Z-00-DX1_{item} - 462 images left
# Already existing file TCGA-44-7659-01Z-00-DX1_{item} - 461 images left
# Already existing file TCGA-44-7660-01Z-00-DX1_{item} - 460 images left
# Already existing file TCGA-44-7661-01Z-00-DX1_{item} - 459 images left
# Already existing file TCGA-44-7662-01Z-00-DX1_{item} - 458 images left
# Already existing file TCGA-44-7667-01Z-00-DX1_{item} - 457 images left
# Already existing file TCGA-44-7669-01Z-00-DX1_{item} - 456 images left
# Already existing file TCGA-44-7670-01Z-00-DX1_{item} - 455 images left
# Already existing file TCGA-44-7671-01Z-00-DX1_{item} - 454 images left
# Already existing file TCGA-44-7672-01Z-00-DX1_{item} - 453 images left
# Already existing file TCGA-44-8119-01Z-00-DX1_{item} - 452 images left
# Already existing file TCGA-44-A479-01Z-00-DX1_{item} - 451 images left
# Already existing file TCGA-44-A47A-01Z-00-DX1_{item} - 450 images left
# Already existing file TCGA-44-A47B-01Z-00-DX1_{item} - 449 images left
# Already existing file TCGA-44-A47F-01Z-00-DX1_{item} - 448 images left
# Already existing file TCGA-44-A47G-01Z-00-DX1_{item} - 447 images left
# Already existing file TCGA-44-A4SS-01Z-00-DX1_{item} - 446 images left
# Already existing file TCGA-44-A4SU-01Z-00-DX1_{item} - 445 images left
# Already existing file TCGA-49-4487-01Z-00-DX1_{item} - 444 images left
# Already existing file TCGA-49-4488-01Z-00-DX10_{item} - 443 images left
# Already existing file TCGA-49-4488-01Z-00-DX1_{item} - 442 images left
# Already existing file TCGA-49-4488-01Z-00-DX2_{item} - 441 images left
# Already existing file TCGA-49-4488-01Z-00-DX3_{item} - 440 images left
# Already existing file TCGA-49-4488-01Z-00-DX4_{item} - 439 images left
# Already existing file TCGA-49-4488-01Z-00-DX5_{item} - 438 images left
# Already existing file TCGA-49-4488-01Z-00-DX6_{item} - 437 images left
# Already existing file TCGA-49-4488-01Z-00-DX7_{item} - 436 images left
# Already existing file TCGA-49-4488-01Z-00-DX8_{item} - 435 images left
# Already existing file TCGA-49-4488-01Z-00-DX9_{item} - 434 images left
# Already existing file TCGA-49-4490-01Z-00-DX1_{item} - 433 images left
# Already existing file TCGA-49-4490-01Z-00-DX2_{item} - 432 images left
# Already existing file TCGA-49-4490-01Z-00-DX3_{item} - 431 images left
# Already existing file TCGA-49-4490-01Z-00-DX4_{item} - 430 images left
# Already existing file TCGA-49-4490-01Z-00-DX5_{item} - 429 images left
# Already existing file TCGA-49-4490-01Z-00-DX6_{item} - 428 images left
# Already existing file TCGA-49-4494-01Z-00-DX1_{item} - 427 images left
# Already existing file TCGA-49-4494-01Z-00-DX2_{item} - 426 images left
# Already existing file TCGA-49-4494-01Z-00-DX3_{item} - 425 images left
# Already existing file TCGA-49-4494-01Z-00-DX4_{item} - 424 images left
# Already existing file TCGA-49-4494-01Z-00-DX5_{item} - 423 images left
# Already existing file TCGA-49-4494-01Z-00-DX6_{item} - 422 images left
# Already existing file TCGA-49-4494-01Z-00-DX7_{item} - 421 images left
# Already existing file TCGA-49-4501-01Z-00-DX1_{item} - 420 images left
# Already existing file TCGA-49-4501-01Z-00-DX2_{item} - 419 images left
# Already existing file TCGA-49-4501-01Z-00-DX3_{item} - 418 images left
# Already existing file TCGA-49-4505-01Z-00-DX1_{item} - 417 images left
# Already existing file TCGA-49-4505-01Z-00-DX2_{item} - 416 images left
# Already existing file TCGA-49-4505-01Z-00-DX3_{item} - 415 images left
# Already existing file TCGA-49-4505-01Z-00-DX4_{item} - 414 images left
# Already existing file TCGA-49-4506-01Z-00-DX1_{item} - 413 images left
# Already existing file TCGA-49-4506-01Z-00-DX2_{item} - 412 images left
# Already existing file TCGA-49-4506-01Z-00-DX3_{item} - 411 images left
# Already existing file TCGA-49-4506-01Z-00-DX4_{item} - 410 images left
# Already existing file TCGA-49-4507-01Z-00-DX1_{item} - 409 images left
# Already existing file TCGA-49-4507-01Z-00-DX2_{item} - 408 images left
# Already existing file TCGA-49-4510-01Z-00-DX1_{item} - 407 images left
# Already existing file TCGA-49-4510-01Z-00-DX2_{item} - 406 images left
# Already existing file TCGA-49-4512-01Z-00-DX1_{item} - 405 images left
# Already existing file TCGA-49-4512-01Z-00-DX2_{item} - 404 images left
# Already existing file TCGA-49-4512-01Z-00-DX3_{item} - 403 images left
# Already existing file TCGA-49-4512-01Z-00-DX4_{item} - 402 images left
# Already existing file TCGA-49-4512-01Z-00-DX5_{item} - 401 images left
# Already existing file TCGA-49-4512-01Z-00-DX6_{item} - 400 images left
# Already existing file TCGA-49-4512-01Z-00-DX7_{item} - 399 images left
# Already existing file TCGA-49-4512-01Z-00-DX8_{item} - 398 images left
# Already existing file TCGA-49-4514-01Z-00-DX1_{item} - 397 images left
# Already existing file TCGA-49-4514-01Z-00-DX2_{item} - 396 images left
# Already existing file TCGA-49-4514-01Z-00-DX3_{item} - 395 images left
# Already existing file TCGA-49-4514-01Z-00-DX4_{item} - 394 images left
# Already existing file TCGA-49-6742-01Z-00-DX1_{item} - 393 images left
# Already existing file TCGA-49-6742-01Z-00-DX2_{item} - 392 images left
# Already existing file TCGA-49-6742-01Z-00-DX3_{item} - 391 images left
# Already existing file TCGA-49-6742-01Z-00-DX4_{item} - 390 images left
# Already existing file TCGA-49-6742-01Z-00-DX5_{item} - 389 images left
# Already existing file TCGA-49-6743-01Z-00-DX1_{item} - 388 images left
# Already existing file TCGA-49-6743-01Z-00-DX2_{item} - 387 images left
# Already existing file TCGA-49-6743-01Z-00-DX3_{item} - 386 images left
# Already existing file TCGA-49-6743-01Z-00-DX4_{item} - 385 images left
# Already existing file TCGA-49-6744-01Z-00-DX1_{item} - 384 images left
# Already existing file TCGA-49-6744-01Z-00-DX2_{item} - 383 images left
# Already existing file TCGA-49-6744-01Z-00-DX3_{item} - 382 images left
# Already existing file TCGA-49-6744-01Z-00-DX4_{item} - 381 images left
# Already existing file TCGA-49-6745-01Z-00-DX1_{item} - 380 images left
# Already existing file TCGA-49-6745-01Z-00-DX2_{item} - 379 images left
# Already existing file TCGA-49-6745-01Z-00-DX3_{item} - 378 images left
# Already existing file TCGA-49-6745-01Z-00-DX4_{item} - 377 images left
# Already existing file TCGA-49-6745-01Z-00-DX5_{item} - 376 images left
# Already existing file TCGA-49-6745-01Z-00-DX6_{item} - 375 images left
# Already existing file TCGA-49-6745-01Z-00-DX7_{item} - 374 images left
# Already existing file TCGA-49-6761-01Z-00-DX1_{item} - 373 images left
# Already existing file TCGA-49-6767-01Z-00-DX1_{item} - 372 images left
# Already existing file TCGA-49-AAQV-01Z-00-DX1_{item} - 371 images left
# Already existing file TCGA-49-AAR0-01Z-00-DX1_{item} - 370 images left
# Already existing file TCGA-49-AAR2-01Z-00-DX1_{item} - 369 images left
# Already existing file TCGA-49-AAR3-01Z-00-DX1_{item} - 368 images left
# Already existing file TCGA-49-AAR4-01Z-00-DX1_{item} - 367 images left
# Already existing file TCGA-49-AAR9-01Z-00-DX1_{item} - 366 images left
# Already existing file TCGA-49-AARE-01Z-00-DX1_{item} - 365 images left
# Already existing file TCGA-49-AARN-01Z-00-DX1_{item} - 364 images left
# Already existing file TCGA-49-AARO-01Z-00-DX1_{item} - 363 images left
# Already existing file TCGA-49-AARQ-01Z-00-DX1_{item} - 362 images left
# Already existing file TCGA-49-AARR-01Z-00-DX1_{item} - 361 images left
# Already existing file TCGA-4B-A93V-01Z-00-DX1_{item} - 360 images left
# Already existing file TCGA-50-5044-01Z-00-DX1_{item} - 359 images left
# Already existing file TCGA-50-5045-01Z-00-DX1_{item} - 358 images left
# Already existing file TCGA-50-5045-01Z-00-DX2_{item} - 357 images left
# Already existing file TCGA-50-5055-01Z-00-DX1_{item} - 356 images left
# Already existing file TCGA-50-5055-01Z-00-DX2_{item} - 355 images left
# Already existing file TCGA-50-5066-01Z-00-DX1_{item} - 354 images left
# Already existing file TCGA-50-5066-02Z-00-DX1_{item} - 353 images left
# Already existing file TCGA-50-5068-01Z-00-DX1_{item} - 352 images left
# Already existing file TCGA-50-5068-01Z-00-DX2_{item} - 351 images left
# Already existing file TCGA-50-5931-01Z-00-DX1_{item} - 350 images left
# Already existing file TCGA-50-5939-01Z-00-DX1_{item} - 349 images left
# Already existing file TCGA-50-5942-01Z-00-DX1_{item} - 348 images left
# Already existing file TCGA-50-5946-01Z-00-DX1_{item} - 347 images left
# Already existing file TCGA-50-6590-01Z-00-DX1_{item} - 346 images left
# Already existing file TCGA-50-6591-01Z-00-DX1_{item} - 345 images left
# Already existing file TCGA-50-6593-01Z-00-DX1_{item} - 344 images left
# Already existing file TCGA-50-6594-01Z-00-DX1_{item} - 343 images left
# Already existing file TCGA-50-6597-01Z-00-DX1_{item} - 342 images left
# Already existing file TCGA-50-6673-01Z-00-DX1_{item} - 341 images left
# Already existing file TCGA-50-7109-01Z-00-DX1_{item} - 340 images left
# Already existing file TCGA-50-8457-01Z-00-DX1_{item} - 339 images left
# Already existing file TCGA-50-8459-01Z-00-DX1_{item} - 338 images left
# Already existing file TCGA-53-7624-01Z-00-DX1_{item} - 337 images left
# Already existing file TCGA-53-7626-01Z-00-DX1_{item} - 336 images left
# Already existing file TCGA-53-7813-01Z-00-DX1_{item} - 335 images left
# Already existing file TCGA-53-A4EZ-01Z-00-DX1_{item} - 334 images left
# Already existing file TCGA-55-1592-01Z-00-DX1_{item} - 333 images left
# Already existing file TCGA-55-1594-01Z-00-DX1_{item} - 332 images left
# Already existing file TCGA-55-1595-01Z-00-DX1_{item} - 331 images left
# Already existing file TCGA-55-1596-01Z-00-DX1_{item} - 330 images left
# Already existing file TCGA-55-5899-01Z-00-DX1_{item} - 329 images left
# Already existing file TCGA-55-6543-01Z-00-DX1_{item} - 328 images left
# Already existing file TCGA-55-6642-01Z-00-DX1_{item} - 327 images left
# Already existing file TCGA-55-6712-01Z-00-DX1_{item} - 326 images left
# Already existing file TCGA-55-6968-01Z-00-DX1_{item} - 325 images left
# Already existing file TCGA-55-6969-01Z-00-DX1_{item} - 324 images left
# Already existing file TCGA-55-6970-01Z-00-DX1_{item} - 323 images left
# Already existing file TCGA-55-6971-01Z-00-DX1_{item} - 322 images left
# Already existing file TCGA-55-6972-01Z-00-DX1_{item} - 321 images left
# Already existing file TCGA-55-6975-01Z-00-DX1_{item} - 320 images left
# Already existing file TCGA-55-6978-01Z-00-DX1_{item} - 319 images left
# Already existing file TCGA-55-6979-01Z-00-DX1_{item} - 318 images left
# Already existing file TCGA-55-6980-01Z-00-DX1_{item} - 317 images left
# Already existing file TCGA-55-6981-01Z-00-DX1_{item} - 316 images left
# Already existing file TCGA-55-6982-01Z-00-DX1_{item} - 315 images left
# Already existing file TCGA-55-6983-01Z-00-DX1_{item} - 314 images left
# Already existing file TCGA-55-6984-01Z-00-DX1_{item} - 313 images left
# Already existing file TCGA-55-6985-01Z-00-DX1_{item} - 312 images left
# Already existing file TCGA-55-6986-01Z-00-DX1_{item} - 311 images left
# Already existing file TCGA-55-6987-01Z-00-DX1_{item} - 310 images left
# Already existing file TCGA-55-7227-01Z-00-DX1_{item} - 309 images left
# Already existing file TCGA-55-7281-01Z-00-DX1_{item} - 308 images left
# Already existing file TCGA-55-7283-01Z-00-DX1_{item} - 307 images left
# Already existing file TCGA-55-7284-01Z-00-DX1_{item} - 306 images left
# Already existing file TCGA-55-7570-01Z-00-DX1_{item} - 305 images left
# Already existing file TCGA-55-7573-01Z-00-DX1_{item} - 304 images left
# Already existing file TCGA-55-7574-01Z-00-DX1_{item} - 303 images left
# Already existing file TCGA-55-7576-01Z-00-DX1_{item} - 302 images left
# Already existing file TCGA-55-7724-01Z-00-DX1_{item} - 301 images left
# Already existing file TCGA-55-7725-01Z-00-DX1_{item} - 300 images left
# Already existing file TCGA-55-7726-01Z-00-DX1_{item} - 299 images left
# Already existing file TCGA-55-7727-01Z-00-DX1_{item} - 298 images left
# Already existing file TCGA-55-7728-01Z-00-DX1_{item} - 297 images left
# Already existing file TCGA-55-7815-01Z-00-DX1_{item} - 296 images left
# Already existing file TCGA-55-7816-01Z-00-DX1_{item} - 295 images left
# Already existing file TCGA-55-7903-01Z-00-DX1_{item} - 294 images left
# Already existing file TCGA-55-7907-01Z-00-DX1_{item} - 293 images left
# Already existing file TCGA-55-7910-01Z-00-DX1_{item} - 292 images left
# Already existing file TCGA-55-7911-01Z-00-DX1_{item} - 291 images left
# Already existing file TCGA-55-7913-01Z-00-DX1_{item} - 290 images left
# Already existing file TCGA-55-7914-01Z-00-DX1_{item} - 289 images left
# Already existing file TCGA-55-7994-01Z-00-DX1_{item} - 288 images left
# Already existing file TCGA-55-7995-01Z-00-DX1_{item} - 287 images left
# Already existing file TCGA-55-8085-01Z-00-DX1_{item} - 286 images left
# Already existing file TCGA-55-8087-01Z-00-DX1_{item} - 285 images left
# Already existing file TCGA-55-8089-01Z-00-DX1_{item} - 284 images left
# Already existing file TCGA-55-8090-01Z-00-DX1_{item} - 283 images left
# Already existing file TCGA-55-8091-01Z-00-DX1_{item} - 282 images left
# Already existing file TCGA-55-8092-01Z-00-DX1_{item} - 281 images left
# Already existing file TCGA-55-8094-01Z-00-DX1_{item} - 280 images left
# Already existing file TCGA-55-8096-01Z-00-DX1_{item} - 279 images left
# Already existing file TCGA-55-8097-01Z-00-DX1_{item} - 278 images left
# Already existing file TCGA-55-8203-01Z-00-DX1_{item} - 277 images left
# Already existing file TCGA-55-8204-01Z-00-DX1_{item} - 276 images left
# Already existing file TCGA-55-8205-01Z-00-DX1_{item} - 275 images left
# Already existing file TCGA-55-8206-01Z-00-DX1_{item} - 274 images left
# Already existing file TCGA-55-8207-01Z-00-DX1_{item} - 273 images left
# Already existing file TCGA-55-8208-01Z-00-DX1_{item} - 272 images left
# Already existing file TCGA-55-8299-01Z-00-DX1_{item} - 271 images left
# Already existing file TCGA-55-8301-01Z-00-DX1_{item} - 270 images left
# Already existing file TCGA-55-8302-01Z-00-DX1_{item} - 269 images left
# Already existing file TCGA-55-8505-01Z-00-DX1_{item} - 268 images left
# Already existing file TCGA-55-8506-01Z-00-DX1_{item} - 267 images left
# Already existing file TCGA-55-8507-01Z-00-DX1_{item} - 266 images left
# Already existing file TCGA-55-8508-01Z-00-DX1_{item} - 265 images left
# Already existing file TCGA-55-8510-01Z-00-DX1_{item} - 264 images left
# Already existing file TCGA-55-8511-01Z-00-DX1_{item} - 263 images left
# Already existing file TCGA-55-8512-01Z-00-DX1_{item} - 262 images left
# Already existing file TCGA-55-8513-01Z-00-DX1_{item} - 261 images left
# Already existing file TCGA-55-8514-01Z-00-DX1_{item} - 260 images left
# Already existing file TCGA-55-8614-01Z-00-DX1_{item} - 259 images left
# Already existing file TCGA-55-8615-01Z-00-DX1_{item} - 258 images left
# Already existing file TCGA-55-8616-01Z-00-DX1_{item} - 257 images left
# Already existing file TCGA-55-8619-01Z-00-DX1_{item} - 256 images left
# Already existing file TCGA-55-8620-01Z-00-DX1_{item} - 255 images left
# Already existing file TCGA-55-8621-01Z-00-DX1_{item} - 254 images left
# Already existing file TCGA-55-A48X-01Z-00-DX1_{item} - 253 images left
# Already existing file TCGA-55-A48Y-01Z-00-DX1_{item} - 252 images left
# Already existing file TCGA-55-A48Z-01Z-00-DX1_{item} - 251 images left
# Already existing file TCGA-55-A490-01Z-00-DX1_{item} - 250 images left
# Already existing file TCGA-55-A491-01Z-00-DX1_{item} - 249 images left
# Already existing file TCGA-55-A492-01Z-00-DX1_{item} - 248 images left
# Already existing file TCGA-55-A493-01Z-00-DX1_{item} - 247 images left
# Already existing file TCGA-55-A494-01Z-00-DX1_{item} - 246 images left
# Already existing file TCGA-55-A4DF-01Z-00-DX1_{item} - 245 images left
# Already existing file TCGA-55-A4DG-01Z-00-DX1_{item} - 244 images left
# Already existing file TCGA-55-A57B-01Z-00-DX1_{item} - 243 images left
# Already existing file TCGA-62-A46O-01Z-00-DX1_{item} - 242 images left
# Already existing file TCGA-62-A46P-01Z-00-DX1_{item} - 241 images left
# Already existing file TCGA-62-A46R-01Z-00-DX1_{item} - 240 images left
# Already existing file TCGA-62-A46S-01Z-00-DX1_{item} - 239 images left
# Already existing file TCGA-62-A46U-01Z-00-DX1_{item} - 238 images left
# Already existing file TCGA-62-A46V-01Z-00-DX1_{item} - 237 images left
# Already existing file TCGA-62-A470-01Z-00-DX1_{item} - 236 images left
# Already existing file TCGA-62-A471-01Z-00-DX1_{item} - 235 images left
# Already existing file TCGA-62-A472-01Z-00-DX1_{item} - 234 images left
# Already existing file TCGA-64-1676-01Z-00-DX1_{item} - 233 images left
# Already existing file TCGA-64-1677-01Z-00-DX1_{item} - 232 images left
# Already existing file TCGA-64-1678-01Z-00-DX1_{item} - 231 images left
# Already existing file TCGA-64-1679-01Z-00-DX1_{item} - 230 images left
# Already existing file TCGA-64-1680-01Z-00-DX1_{item} - 229 images left
# Already existing file TCGA-64-1681-01Z-00-DX1_{item} - 228 images left
# Already existing file TCGA-64-5774-01Z-00-DX1_{item} - 227 images left
# Already existing file TCGA-64-5775-01Z-00-DX1_{item} - 226 images left
# Already existing file TCGA-64-5778-01Z-00-DX1_{item} - 225 images left
# Already existing file TCGA-64-5779-01Z-00-DX1_{item} - 224 images left
# Already existing file TCGA-64-5781-01Z-00-DX1_{item} - 223 images left
# Already existing file TCGA-64-5815-01Z-00-DX1_{item} - 222 images left
# Already existing file TCGA-67-3770-01Z-00-DX1_{item} - 221 images left
# Already existing file TCGA-67-3771-01Z-00-DX1_{item} - 220 images left
# Already existing file TCGA-67-3772-01Z-00-DX1_{item} - 219 images left
# Already existing file TCGA-67-3773-01Z-00-DX1_{item} - 218 images left
# Already existing file TCGA-67-3774-01Z-00-DX1_{item} - 217 images left
# Already existing file TCGA-67-4679-01Z-00-DX1_{item} - 216 images left
# Already existing file TCGA-67-6215-01Z-00-DX1_{item} - 215 images left
# Already existing file TCGA-67-6216-01Z-00-DX1_{item} - 214 images left
# Already existing file TCGA-67-6217-01Z-00-DX1_{item} - 213 images left
# Already existing file TCGA-69-7760-01Z-00-DX1_{item} - 212 images left
# Already existing file TCGA-69-7761-01Z-00-DX1_{item} - 211 images left
# Already existing file TCGA-69-7763-01Z-00-DX1_{item} - 210 images left
# Already existing file TCGA-69-7764-01Z-00-DX1_{item} - 209 images left
# Already existing file TCGA-69-7765-01Z-00-DX1_{item} - 208 images left
# Already existing file TCGA-69-7973-01Z-00-DX1_{item} - 207 images left
# Already existing file TCGA-69-7974-01Z-00-DX1_{item} - 206 images left
# Already existing file TCGA-69-7978-01Z-00-DX1_{item} - 205 images left
# Already existing file TCGA-69-7979-01Z-00-DX1_{item} - 204 images left
# Already existing file TCGA-69-7980-01Z-00-DX1_{item} - 203 images left
# Already existing file TCGA-69-8253-01Z-00-DX1_{item} - 202 images left
# Already existing file TCGA-69-8254-01Z-00-DX1_{item} - 201 images left
# Already existing file TCGA-69-8255-01Z-00-DX1_{item} - 200 images left
# Already existing file TCGA-69-8453-01Z-00-DX1_{item} - 199 images left
# Already existing file TCGA-69-A59K-01Z-00-DX1_{item} - 198 images left
# Already existing file TCGA-71-6725-01Z-00-DX1_{item} - 197 images left
# Already existing file TCGA-71-8520-01Z-00-DX1_{item} - 196 images left
# Already existing file TCGA-73-4658-01Z-00-DX1_{item} - 195 images left
# Already existing file TCGA-73-4659-01Z-00-DX1_{item} - 194 images left
# Already existing file TCGA-73-4662-01Z-00-DX1_{item} - 193 images left
# Already existing file TCGA-73-4666-01Z-00-DX1_{item} - 192 images left
# Already existing file TCGA-73-4668-01Z-00-DX1_{item} - 191 images left
# Already existing file TCGA-73-4670-01Z-00-DX1_{item} - 190 images left
# Already existing file TCGA-73-4675-01Z-00-DX1_{item} - 189 images left
# Already existing file TCGA-73-4676-01Z-00-DX1_{item} - 188 images left
# Already existing file TCGA-73-4677-01Z-00-DX1_{item} - 187 images left
# Already existing file TCGA-73-7498-01Z-00-DX1_{item} - 186 images left
# Already existing file TCGA-73-7499-01Z-00-DX1_{item} - 185 images left
# Already existing file TCGA-73-A9RS-01Z-00-DX1_{item} - 184 images left
# Already existing file TCGA-75-5122-01Z-00-DX1_{item} - 183 images left
# Already existing file TCGA-75-5125-01Z-00-DX1_{item} - 182 images left
# Already existing file TCGA-75-5126-01Z-00-DX1_{item} - 181 images left
# Already existing file TCGA-75-5146-01Z-00-DX1_{item} - 180 images left
# Already existing file TCGA-75-5147-01Z-00-DX1_{item} - 179 images left
# Already existing file TCGA-75-6203-01Z-00-DX1_{item} - 178 images left
# Already existing file TCGA-75-6205-01Z-00-DX1_{item} - 177 images left
# Already existing file TCGA-75-6206-01Z-00-DX1_{item} - 176 images left
# Already existing file TCGA-75-6207-01Z-00-DX1_{item} - 175 images left
# Already existing file TCGA-75-6211-01Z-00-DX1_{item} - 174 images left
# Already existing file TCGA-75-6212-01Z-00-DX1_{item} - 173 images left
# Already existing file TCGA-75-6214-01Z-00-DX1_{item} - 172 images left
# Already existing file TCGA-75-7025-01Z-00-DX1_{item} - 171 images left
# Already existing file TCGA-75-7027-01Z-00-DX1_{item} - 170 images left
# Already existing file TCGA-75-7030-01Z-00-DX1_{item} - 169 images left
# Already existing file TCGA-75-7031-01Z-00-DX1_{item} - 168 images left
# Already existing file TCGA-78-7145-01Z-00-DX1_{item} - 167 images left
# Already existing file TCGA-78-7146-01Z-00-DX1_{item} - 166 images left
# Already existing file TCGA-78-7147-01Z-00-DX1_{item} - 165 images left
# Already existing file TCGA-78-7148-01Z-00-DX1_{item} - 164 images left
# Already existing file TCGA-78-7149-01Z-00-DX1_{item} - 163 images left
# Already existing file TCGA-78-7150-01Z-00-DX1_{item} - 162 images left
# Already existing file TCGA-78-7152-01Z-00-DX1_{item} - 161 images left
# Already existing file TCGA-78-7153-01Z-00-DX1_{item} - 160 images left
# Already existing file TCGA-78-7154-01Z-00-DX1_{item} - 159 images left
# Already existing file TCGA-78-7155-01Z-00-DX1_{item} - 158 images left
# Already existing file TCGA-78-7156-01Z-00-DX1_{item} - 157 images left
# Already existing file TCGA-78-7158-01Z-00-DX1_{item} - 156 images left
# Already existing file TCGA-78-7159-01Z-00-DX1_{item} - 155 images left
# Already existing file TCGA-78-7160-01Z-00-DX1_{item} - 154 images left
# Already existing file TCGA-78-7161-01Z-00-DX1_{item} - 153 images left
# Already existing file TCGA-78-7163-01Z-00-DX1_{item} - 152 images left
# Already existing file TCGA-78-7166-01Z-00-DX1_{item} - 151 images left
# Already existing file TCGA-78-7167-01Z-00-DX1_{item} - 150 images left
# Already existing file TCGA-78-7220-01Z-00-DX1_{item} - 149 images left
# Already existing file TCGA-78-7535-01Z-00-DX1_{item} - 148 images left
# Already existing file TCGA-78-7536-01Z-00-DX1_{item} - 147 images left
# Already existing file TCGA-78-7537-01Z-00-DX1_{item} - 146 images left
# Already existing file TCGA-78-7539-01Z-00-DX1_{item} - 145 images left
# Already existing file TCGA-78-7540-01Z-00-DX1_{item} - 144 images left
# Already existing file TCGA-78-7542-01Z-00-DX1_{item} - 143 images left
# Already existing file TCGA-78-7633-01Z-00-DX1_{item} - 142 images left
# Already existing file TCGA-78-8640-01Z-00-DX1_{item} - 141 images left
# Already existing file TCGA-78-8648-01Z-00-DX1_{item} - 140 images left
# Already existing file TCGA-78-8655-01Z-00-DX1_{item} - 139 images left
# Already existing file TCGA-78-8660-01Z-00-DX1_{item} - 138 images left
# Already existing file TCGA-78-8662-01Z-00-DX1_{item} - 137 images left
# Already existing file TCGA-80-5607-01Z-00-DX1_{item} - 136 images left
# Already existing file TCGA-80-5608-01Z-00-DX1_{item} - 135 images left
# Already existing file TCGA-80-5611-01Z-00-DX1_{item} - 134 images left
# Already existing file TCGA-83-5908-01Z-00-DX1_{item} - 133 images left
# Already existing file TCGA-86-6562-01Z-00-DX1_{item} - 132 images left
# Already existing file TCGA-86-6851-01Z-00-DX1_{item} - 131 images left
# Already existing file TCGA-86-7701-01Z-00-DX1_{item} - 130 images left
# Already existing file TCGA-86-7711-01Z-00-DX1_{item} - 129 images left
# Already existing file TCGA-86-7713-01Z-00-DX1_{item} - 128 images left
# Already existing file TCGA-86-7714-01Z-00-DX1_{item} - 127 images left
# Already existing file TCGA-86-7953-01Z-00-DX1_{item} - 126 images left
# Already existing file TCGA-86-7954-01Z-00-DX1_{item} - 125 images left
# Already existing file TCGA-86-7955-01Z-00-DX1_{item} - 124 images left
# Already existing file TCGA-86-8054-01Z-00-DX1_{item} - 123 images left
# Already existing file TCGA-86-8055-01Z-00-DX1_{item} - 122 images left
# Already existing file TCGA-86-8056-01Z-00-DX1_{item} - 121 images left
# Already existing file TCGA-86-8073-01Z-00-DX1_{item} - 120 images left
# Already existing file TCGA-86-8074-01Z-00-DX1_{item} - 119 images left
# Already existing file TCGA-86-8075-01Z-00-DX1_{item} - 118 images left
# Already existing file TCGA-86-8076-01Z-00-DX1_{item} - 117 images left
# Already existing file TCGA-86-8278-01Z-00-DX1_{item} - 116 images left
# Already existing file TCGA-86-8279-01Z-00-DX1_{item} - 115 images left
# Already existing file TCGA-86-8280-01Z-00-DX1_{item} - 114 images left
# Already existing file TCGA-86-8281-01Z-00-DX1_{item} - 113 images left
# Already existing file TCGA-86-8358-01Z-00-DX1_{item} - 112 images left
# Already existing file TCGA-86-8359-01Z-00-DX1_{item} - 111 images left
# Already existing file TCGA-86-8585-01Z-00-DX1_{item} - 110 images left
# Already existing file TCGA-86-8668-01Z-00-DX1_{item} - 109 images left
# Already existing file TCGA-86-8669-01Z-00-DX1_{item} - 108 images left
# Already existing file TCGA-86-8671-01Z-00-DX1_{item} - 107 images left
# Already existing file TCGA-86-8672-01Z-00-DX1_{item} - 106 images left
# Already existing file TCGA-86-8673-01Z-00-DX1_{item} - 105 images left
# Already existing file TCGA-86-8674-01Z-00-DX1_{item} - 104 images left
# Already existing file TCGA-86-A456-01Z-00-DX1_{item} - 103 images left
# Already existing file TCGA-86-A4D0-01Z-00-DX1_{item} - 102 images left
# Already existing file TCGA-86-A4JF-01Z-00-DX1_{item} - 101 images left
# Already existing file TCGA-86-A4P7-01Z-00-DX1_{item} - 100 images left
# Already existing file TCGA-86-A4P8-01Z-00-DX1_{item} - 99 images left
# Already existing file TCGA-91-A4BC-01Z-00-DX1_{item} - 98 images left
# Already existing file TCGA-91-A4BD-01Z-00-DX1_{item} - 97 images left
# Already existing file TCGA-93-7347-01Z-00-DX1_{item} - 96 images left
# Already existing file TCGA-93-7348-01Z-00-DX1_{item} - 95 images left
# Already existing file TCGA-93-8067-01Z-00-DX1_{item} - 94 images left
# Already existing file TCGA-93-A4JN-01Z-00-DX1_{item} - 93 images left
# Already existing file TCGA-93-A4JO-01Z-00-DX1_{item} - 92 images left
# Already existing file TCGA-93-A4JP-01Z-00-DX1_{item} - 91 images left
# Already existing file TCGA-93-A4JQ-01Z-00-DX1_{item} - 90 images left
# Already existing file TCGA-95-7039-01Z-00-DX1_{item} - 89 images left
# Already existing file TCGA-95-7043-01Z-00-DX1_{item} - 88 images left
# Already existing file TCGA-95-7562-01Z-00-DX1_{item} - 87 images left
# Already existing file TCGA-95-7567-01Z-00-DX1_{item} - 86 images left
# Already existing file TCGA-95-7944-01Z-00-DX1_{item} - 85 images left
# Already existing file TCGA-95-7947-01Z-00-DX1_{item} - 84 images left
# Already existing file TCGA-95-7948-01Z-00-DX1_{item} - 83 images left
# Already existing file TCGA-95-8039-01Z-00-DX1_{item} - 82 images left
# Already existing file TCGA-95-8494-01Z-00-DX1_{item} - 81 images left
# Already existing file TCGA-95-A4VK-01Z-00-DX1_{item} - 80 images left
# Already existing file TCGA-95-A4VN-01Z-00-DX1_{item} - 79 images left
# Already existing file TCGA-95-A4VP-01Z-00-DX1_{item} - 78 images left
# Already existing file TCGA-97-7546-01Z-00-DX1_{item} - 77 images left
# Already existing file TCGA-97-7547-01Z-00-DX1_{item} - 76 images left
# Already existing file TCGA-97-7552-01Z-00-DX1_{item} - 75 images left
# Already existing file TCGA-97-7553-01Z-00-DX1_{item} - 74 images left
# Already existing file TCGA-97-7554-01Z-00-DX1_{item} - 73 images left
# Already existing file TCGA-97-7937-01Z-00-DX1_{item} - 72 images left
# Already existing file TCGA-97-7938-01Z-00-DX1_{item} - 71 images left
# Already existing file TCGA-97-7941-01Z-00-DX1_{item} - 70 images left
# Already existing file TCGA-97-8171-01Z-00-DX1_{item} - 69 images left
# Already existing file TCGA-97-8172-01Z-00-DX1_{item} - 68 images left
# Already existing file TCGA-97-8175-01Z-00-DX1_{item} - 67 images left
# Already existing file TCGA-97-8177-01Z-00-DX1_{item} - 66 images left
# Already existing file TCGA-97-8179-01Z-00-DX1_{item} - 65 images left
# Already existing file TCGA-97-8552-01Z-00-DX1_{item} - 64 images left
# Already existing file TCGA-97-A4LX-01Z-00-DX1_{item} - 63 images left
# Already existing file TCGA-97-A4M0-01Z-00-DX1_{item} - 62 images left
# Already existing file TCGA-97-A4M1-01Z-00-DX1_{item} - 61 images left
# Already existing file TCGA-97-A4M2-01Z-00-DX1_{item} - 60 images left
# Already existing file TCGA-97-A4M3-01Z-00-DX1_{item} - 59 images left
# Already existing file TCGA-97-A4M5-01Z-00-DX1_{item} - 58 images left
# Already existing file TCGA-97-A4M6-01Z-00-DX1_{item} - 57 images left
# Already existing file TCGA-97-A4M7-01Z-00-DX1_{item} - 56 images left
# Already existing file TCGA-97-A4M7-01Z-00-DX2_{item} - 55 images left
# Already existing file TCGA-99-7458-01Z-00-DX1_{item} - 54 images left
# Already existing file TCGA-99-8025-01Z-00-DX1_{item} - 53 images left
# Already existing file TCGA-99-8028-01Z-00-DX1_{item} - 52 images left
# Already existing file TCGA-99-8032-01Z-00-DX1_{item} - 51 images left
# Already existing file TCGA-99-8033-01Z-00-DX1_{item} - 50 images left
# Already existing file TCGA-99-AA5R-01Z-00-DX1_{item} - 49 images left
# Already existing file TCGA-J2-8192-01Z-00-DX1_{item} - 48 images left
# Already existing file TCGA-J2-8194-01Z-00-DX1_{item} - 47 images left
# Already existing file TCGA-J2-A4AD-01Z-00-DX1_{item} - 46 images left
# Already existing file TCGA-J2-A4AE-01Z-00-DX1_{item} - 45 images left
# Already existing file TCGA-J2-A4AG-01Z-00-DX1_{item} - 44 images left
# Already existing file TCGA-L4-A4E5-01Z-00-DX1_{item} - 43 images left
# Already existing file TCGA-L4-A4E6-01Z-00-DX1_{item} - 42 images left
# Already existing file TCGA-L9-A443-01Z-00-DX1_{item} - 41 images left
# Already existing file TCGA-L9-A444-01Z-00-DX1_{item} - 40 images left
# Already existing file TCGA-L9-A50W-01Z-00-DX1_{item} - 39 images left
# Already existing file TCGA-L9-A5IP-01Z-00-DX1_{item} - 38 images left
# Already existing file TCGA-L9-A743-01Z-00-DX1_{item} - 37 images left
# Already existing file TCGA-L9-A7SV-01Z-00-DX1_{item} - 36 images left
# Already existing file TCGA-L9-A8F4-01Z-00-DX1_{item} - 35 images left
# Already existing file TCGA-MN-A4N1-01Z-00-DX1_{item} - 34 images left
# Already existing file TCGA-MN-A4N1-01Z-00-DX2_{item} - 33 images left
# Already existing file TCGA-MN-A4N4-01Z-00-DX1_{item} - 32 images left
# Already existing file TCGA-MN-A4N4-01Z-00-DX2_{item} - 31 images left
# Already existing file TCGA-MN-A4N5-01Z-00-DX1_{item} - 30 images left
# Already existing file TCGA-MP-A4SV-01Z-00-DX1_{item} - 29 images left
# Already existing file TCGA-MP-A4SW-01Z-00-DX1_{item} - 28 images left
# Already existing file TCGA-MP-A4SY-01Z-00-DX1_{item} - 27 images left
# Already existing file TCGA-MP-A4T2-01Z-00-DX1_{item} - 26 images left
# Already existing file TCGA-MP-A4T4-01Z-00-DX1_{item} - 25 images left
# Already existing file TCGA-MP-A4T6-01Z-00-DX1_{item} - 24 images left
# Already existing file TCGA-MP-A4T7-01Z-00-DX1_{item} - 23 images left
# Already existing file TCGA-MP-A4T8-01Z-00-DX1_{item} - 22 images left
# Already existing file TCGA-MP-A4T9-01Z-00-DX1_{item} - 21 images left
# Already existing file TCGA-MP-A4TA-01Z-00-DX1_{item} - 20 images left
# Already existing file TCGA-MP-A4TC-01Z-00-DX1_{item} - 19 images left
# Already existing file TCGA-MP-A4TD-01Z-00-DX1_{item} - 18 images left
# Already existing file TCGA-MP-A4TE-01Z-00-DX1_{item} - 17 images left
# Already existing file TCGA-MP-A4TF-01Z-00-DX1_{item} - 16 images left
# Already existing file TCGA-MP-A4TH-01Z-00-DX1_{item} - 15 images left
# Already existing file TCGA-MP-A4TI-01Z-00-DX1_{item} - 14 images left
# Already existing file TCGA-MP-A4TJ-01Z-00-DX1_{item} - 13 images left
# Already existing file TCGA-MP-A4TK-01Z-00-DX1_{item} - 12 images left
# Already existing file TCGA-MP-A5C7-01Z-00-DX1_{item} - 11 images left
# Already existing file TCGA-NJ-A4YF-01Z-00-DX1_{item} - 10 images left
# Already existing file TCGA-NJ-A4YG-01Z-00-DX1_{item} - 9 images left
# Already existing file TCGA-NJ-A4YI-01Z-00-DX1_{item} - 8 images left
# Already existing file TCGA-NJ-A4YP-01Z-00-DX1_{item} - 7 images left
# Already existing file TCGA-NJ-A4YQ-01Z-00-DX1_{item} - 6 images left
# Already existing file TCGA-NJ-A55A-01Z-00-DX1_{item} - 5 images left
# Already existing file TCGA-NJ-A55O-01Z-00-DX1_{item} - 4 images left
# Already existing file TCGA-NJ-A55R-01Z-00-DX1_{item} - 3 images left
# Already existing file TCGA-NJ-A7XG-01Z-00-DX1_{item} - 2 images left
# Already existing file TCGA-O1-A52J-01Z-00-DX1_{item} - 1 images left
# Already existing file TCGA-S2-AA1A-01Z-00-DX1_{item} - 0 images left
# Finish Processing All images!

# %%
# Featurize LUSC data
featurize_images(
    input_dir=vectorized_lusc_dir,
    model_path=model_path, 
    output_dir=featurized_lusc_dir, 
    batch_size=32
    )
# Out:
# Already existing file TCGA-18-3406-01Z-00-DX1_{item} - 505 images left
# Already existing file TCGA-18-3407-01Z-00-DX1_{item} - 504 images left
# Already existing file TCGA-18-3408-01Z-00-DX1_{item} - 503 images left
# Already existing file TCGA-18-3409-01Z-00-DX1_{item} - 502 images left
# Already existing file TCGA-18-3410-01Z-00-DX1_{item} - 501 images left
# Already existing file TCGA-18-3411-01Z-00-DX1_{item} - 500 images left
# Already existing file TCGA-18-3412-01Z-00-DX1_{item} - 499 images left
# Already existing file TCGA-18-3414-01Z-00-DX1_{item} - 498 images left
# Already existing file TCGA-18-3415-01Z-00-DX1_{item} - 497 images left
# Already existing file TCGA-18-3416-01Z-00-DX1_{item} - 496 images left
# Already existing file TCGA-18-3417-01Z-00-DX1_{item} - 495 images left
# Already existing file TCGA-18-3419-01Z-00-DX1_{item} - 494 images left
# Already existing file TCGA-18-3421-01Z-00-DX1_{item} - 493 images left
# Already existing file TCGA-18-4083-01Z-00-DX1_{item} - 492 images left
# Already existing file TCGA-18-4086-01Z-00-DX1_{item} - 491 images left
# Already existing file TCGA-18-4721-01Z-00-DX1_{item} - 490 images left
# Already existing file TCGA-18-5592-01Z-00-DX1_{item} - 489 images left
# Already existing file TCGA-18-5595-01Z-00-DX1_{item} - 488 images left
# Already existing file TCGA-21-1070-01Z-00-DX1_{item} - 487 images left
# Already existing file TCGA-21-1071-01Z-00-DX1_{item} - 486 images left
# Already existing file TCGA-21-1072-01Z-00-DX1_{item} - 485 images left
# Already existing file TCGA-21-1075-01Z-00-DX1_{item} - 484 images left
# Already existing file TCGA-21-1076-01Z-00-DX1_{item} - 483 images left
# Already existing file TCGA-21-1077-01Z-00-DX1_{item} - 482 images left
# Already existing file TCGA-21-1078-01Z-00-DX1_{item} - 481 images left
# Already existing file TCGA-21-1079-01Z-00-DX1_{item} - 480 images left
# Already existing file TCGA-21-1080-01Z-00-DX1_{item} - 479 images left
# Already existing file TCGA-21-1081-01Z-00-DX1_{item} - 478 images left
# Already existing file TCGA-21-1082-01Z-00-DX1_{item} - 477 images left
# Already existing file TCGA-21-1083-01Z-00-DX1_{item} - 476 images left
# Already existing file TCGA-21-5782-01Z-00-DX1_{item} - 475 images left
# Already existing file TCGA-21-5783-01Z-00-DX1_{item} - 474 images left
# Already existing file TCGA-21-5784-01Z-00-DX1_{item} - 473 images left
# Already existing file TCGA-21-5786-01Z-00-DX1_{item} - 472 images left
# Already existing file TCGA-21-5787-01Z-00-DX1_{item} - 471 images left
# Already existing file TCGA-21-A5DI-01Z-00-DX1_{item} - 470 images left
# Already existing file TCGA-22-0940-01Z-00-DX1_{item} - 469 images left
# Already existing file TCGA-22-0944-01Z-00-DX1_{item} - 468 images left
# Already existing file TCGA-22-1000-01Z-00-DX1_{item} - 467 images left
# Already existing file TCGA-22-1002-01Z-00-DX1_{item} - 466 images left
# Already existing file TCGA-22-1005-01Z-00-DX1_{item} - 465 images left
# Already existing file TCGA-22-1011-01Z-00-DX1_{item} - 464 images left
# Already existing file TCGA-22-1012-01Z-00-DX1_{item} - 463 images left
# Already existing file TCGA-22-1016-01Z-00-DX1_{item} - 462 images left
# Already existing file TCGA-22-1017-01Z-00-DX1_{item} - 461 images left
# Already existing file TCGA-22-4591-01Z-00-DX1_{item} - 460 images left
# Already existing file TCGA-22-4593-01Z-00-DX1_{item} - 459 images left
# Already existing file TCGA-22-4594-01Z-00-DX1_{item} - 458 images left
# Already existing file TCGA-22-4595-01Z-00-DX1_{item} - 457 images left
# Already existing file TCGA-22-4596-01Z-00-DX1_{item} - 456 images left
# Already existing file TCGA-22-4599-01Z-00-DX1_{item} - 455 images left
# Already existing file TCGA-22-4601-01Z-00-DX1_{item} - 454 images left
# Already existing file TCGA-22-4604-01Z-00-DX1_{item} - 453 images left
# Already existing file TCGA-22-4605-01Z-00-DX1_{item} - 452 images left
# Already existing file TCGA-22-4607-01Z-00-DX1_{item} - 451 images left
# Already existing file TCGA-22-4609-01Z-00-DX1_{item} - 450 images left
# Already existing file TCGA-22-4613-01Z-00-DX1_{item} - 449 images left
# Already existing file TCGA-22-5471-01Z-00-DX1_{item} - 448 images left
# Already existing file TCGA-22-5472-01Z-00-DX1_{item} - 447 images left
# Already existing file TCGA-22-5473-01Z-00-DX1_{item} - 446 images left
# Already existing file TCGA-22-5474-01Z-00-DX1_{item} - 445 images left
# Already existing file TCGA-22-5477-01Z-00-DX1_{item} - 444 images left
# Already existing file TCGA-22-5478-01Z-00-DX1_{item} - 443 images left
# Already existing file TCGA-22-5479-01Z-00-DX1_{item} - 442 images left
# Already existing file TCGA-22-5480-01Z-00-DX1_{item} - 441 images left
# Already existing file TCGA-22-5481-01Z-00-DX1_{item} - 440 images left
# Already existing file TCGA-22-5482-01Z-00-DX1_{item} - 439 images left
# Already existing file TCGA-22-5483-01Z-00-DX1_{item} - 438 images left
# Already existing file TCGA-22-5485-01Z-00-DX1_{item} - 437 images left
# Already existing file TCGA-22-5489-01Z-00-DX1_{item} - 436 images left
# Already existing file TCGA-22-5491-01Z-00-DX1_{item} - 435 images left
# Already existing file TCGA-22-5492-01Z-00-DX1_{item} - 434 images left
# Already existing file TCGA-22-A5C4-01Z-00-DX1_{item} - 433 images left
# Already existing file TCGA-33-4532-01Z-00-DX1_{item} - 432 images left
# Already existing file TCGA-33-4532-01Z-00-DX2_{item} - 431 images left
# Already existing file TCGA-33-4532-01Z-00-DX3_{item} - 430 images left
# Already existing file TCGA-33-4533-01Z-00-DX1_{item} - 429 images left
# Already existing file TCGA-33-4533-01Z-00-DX2_{item} - 428 images left
# Already existing file TCGA-33-4533-01Z-00-DX3_{item} - 427 images left
# Already existing file TCGA-33-4533-01Z-00-DX4_{item} - 426 images left
# Already existing file TCGA-33-4533-01Z-00-DX5_{item} - 425 images left
# Already existing file TCGA-33-4538-01Z-00-DX1_{item} - 424 images left
# Already existing file TCGA-33-4538-01Z-00-DX2_{item} - 423 images left
# Already existing file TCGA-33-4538-01Z-00-DX3_{item} - 422 images left
# Already existing file TCGA-33-4538-01Z-00-DX4_{item} - 421 images left
# Already existing file TCGA-33-4538-01Z-00-DX5_{item} - 420 images left
# Already existing file TCGA-33-4538-01Z-00-DX6_{item} - 419 images left
# Already existing file TCGA-33-4538-01Z-00-DX7_{item} - 418 images left
# Already existing file TCGA-33-4538-01Z-00-DX8_{item} - 417 images left
# Already existing file TCGA-33-4538-01Z-00-DX9_{item} - 416 images left
# Already existing file TCGA-33-4547-01Z-00-DX1_{item} - 415 images left
# Already existing file TCGA-33-4547-01Z-00-DX2_{item} - 414 images left
# Already existing file TCGA-33-4547-01Z-00-DX3_{item} - 413 images left
# Already existing file TCGA-33-4547-01Z-00-DX4_{item} - 412 images left
# Already existing file TCGA-33-4547-01Z-00-DX5_{item} - 411 images left
# Already existing file TCGA-33-4547-01Z-00-DX6_{item} - 410 images left
# Already existing file TCGA-33-4547-01Z-00-DX7_{item} - 409 images left
# Already existing file TCGA-33-4566-01Z-00-DX1_{item} - 408 images left
# Already existing file TCGA-33-4582-01Z-00-DX1_{item} - 407 images left
# Already existing file TCGA-33-4583-01Z-00-DX1_{item} - 406 images left
# Already existing file TCGA-33-4583-01Z-00-DX2_{item} - 405 images left
# Already existing file TCGA-33-4583-01Z-00-DX3_{item} - 404 images left
# Already existing file TCGA-33-4583-01Z-00-DX4_{item} - 403 images left
# Already existing file TCGA-33-4583-01Z-00-DX5_{item} - 402 images left
# Already existing file TCGA-33-4586-01Z-00-DX1_{item} - 401 images left
# Already existing file TCGA-33-4586-01Z-00-DX2_{item} - 400 images left
# Already existing file TCGA-33-4587-01Z-00-DX1_{item} - 399 images left
# Already existing file TCGA-33-6738-01Z-00-DX1_{item} - 398 images left
# Already existing file TCGA-33-6738-01Z-00-DX2_{item} - 397 images left
# Already existing file TCGA-33-6738-01Z-00-DX3_{item} - 396 images left
# Already existing file TCGA-33-6738-01Z-00-DX4_{item} - 395 images left
# Already existing file TCGA-33-6738-01Z-00-DX5_{item} - 394 images left
# Already existing file TCGA-33-6738-01Z-00-DX6_{item} - 393 images left
# Already existing file TCGA-33-A4WN-01Z-00-DX1_{item} - 392 images left
# Already existing file TCGA-33-A4WN-01Z-00-DX2_{item} - 391 images left
# Already existing file TCGA-33-A5GW-01Z-00-DX1_{item} - 390 images left
# Already existing file TCGA-33-A5GW-01Z-00-DX2_{item} - 389 images left
# Already existing file TCGA-33-A5GW-01Z-00-DX3_{item} - 388 images left
# Already existing file TCGA-33-AAS8-01Z-00-DX1_{item} - 387 images left
# Already existing file TCGA-33-AASB-01Z-00-DX1_{item} - 386 images left
# Already existing file TCGA-33-AASD-01Z-00-DX1_{item} - 385 images left
# Already existing file TCGA-33-AASI-01Z-00-DX1_{item} - 384 images left
# Already existing file TCGA-33-AASJ-01Z-00-DX1_{item} - 383 images left
# Already existing file TCGA-33-AASL-01Z-00-DX1_{item} - 382 images left
# Already existing file TCGA-34-2596-01Z-00-DX1_{item} - 381 images left
# Already existing file TCGA-34-2600-01Z-00-DX1_{item} - 380 images left
# Already existing file TCGA-34-5232-01Z-00-DX1_{item} - 379 images left
# Already existing file TCGA-34-5240-01Z-00-DX1_{item} - 378 images left
# Already existing file TCGA-34-5241-01Z-00-DX1_{item} - 377 images left
# Already existing file TCGA-34-5928-01Z-00-DX1_{item} - 376 images left
# Already existing file TCGA-34-5929-01Z-00-DX1_{item} - 375 images left
# Already existing file TCGA-34-7107-01Z-00-DX1_{item} - 374 images left
# Already existing file TCGA-34-8454-01Z-00-DX1_{item} - 373 images left
# Already existing file TCGA-34-8455-01Z-00-DX1_{item} - 372 images left
# Already existing file TCGA-34-A5IX-01Z-00-DX1_{item} - 371 images left
# Already existing file TCGA-37-3783-01Z-00-DX1_{item} - 370 images left
# Already existing file TCGA-37-3789-01Z-00-DX1_{item} - 369 images left
# Already existing file TCGA-37-3792-01Z-00-DX1_{item} - 368 images left
# Already existing file TCGA-37-4129-01Z-00-DX1_{item} - 367 images left
# Already existing file TCGA-37-4130-01Z-00-DX1_{item} - 366 images left
# Already existing file TCGA-37-4132-01Z-00-DX1_{item} - 365 images left
# Already existing file TCGA-37-4133-01Z-00-DX1_{item} - 364 images left
# Already existing file TCGA-37-4135-01Z-00-DX1_{item} - 363 images left
# Already existing file TCGA-37-4141-01Z-00-DX1_{item} - 362 images left
# Already existing file TCGA-37-5819-01Z-00-DX1_{item} - 361 images left
# Already existing file TCGA-37-A5EL-01Z-00-DX1_{item} - 360 images left
# Already existing file TCGA-37-A5EM-01Z-00-DX1_{item} - 359 images left
# Already existing file TCGA-37-A5EN-01Z-00-DX1_{item} - 358 images left
# Already existing file TCGA-39-5011-01Z-00-DX1_{item} - 357 images left
# Already existing file TCGA-39-5016-01Z-00-DX1_{item} - 356 images left
# Already existing file TCGA-39-5019-01Z-00-DX1_{item} - 355 images left
# Already existing file TCGA-39-5021-01Z-00-DX1_{item} - 354 images left
# Already existing file TCGA-39-5022-01Z-00-DX1_{item} - 353 images left
# Already existing file TCGA-39-5024-01Z-00-DX1_{item} - 352 images left
# Already existing file TCGA-39-5027-01Z-00-DX1_{item} - 351 images left
# Already existing file TCGA-39-5028-01Z-00-DX1_{item} - 350 images left
# Already existing file TCGA-39-5029-01Z-00-DX1_{item} - 349 images left
# Already existing file TCGA-39-5030-01Z-00-DX1_{item} - 348 images left
# Already existing file TCGA-39-5031-01Z-00-DX1_{item} - 347 images left
# Already existing file TCGA-39-5034-01Z-00-DX1_{item} - 346 images left
# Already existing file TCGA-39-5035-01Z-00-DX1_{item} - 345 images left
# Already existing file TCGA-39-5036-01Z-00-DX1_{item} - 344 images left
# Already existing file TCGA-39-5037-01Z-00-DX1_{item} - 343 images left
# Already existing file TCGA-39-5039-01Z-00-DX1_{item} - 342 images left
# Already existing file TCGA-39-5040-01Z-00-DX1_{item} - 341 images left
# Already existing file TCGA-43-2576-01Z-00-DX1_{item} - 340 images left
# Already existing file TCGA-43-2578-01Z-00-DX1_{item} - 339 images left
# Already existing file TCGA-43-2581-01Z-00-DX1_{item} - 338 images left
# Already existing file TCGA-43-3394-01Z-00-DX1_{item} - 337 images left
# Already existing file TCGA-43-3920-01Z-00-DX1_{item} - 336 images left
# Already existing file TCGA-43-5668-01Z-00-DX1_{item} - 335 images left
# Already existing file TCGA-43-5670-01Z-00-DX1_{item} - 334 images left
# Already existing file TCGA-43-6143-01Z-00-DX1_{item} - 333 images left
# Already existing file TCGA-43-6647-01Z-00-DX1_{item} - 332 images left
# Already existing file TCGA-43-6770-01Z-00-DX1_{item} - 331 images left
# Already existing file TCGA-43-6771-01Z-00-DX1_{item} - 330 images left
# Already existing file TCGA-43-6773-01Z-00-DX1_{item} - 329 images left
# Already existing file TCGA-43-7656-01Z-00-DX1_{item} - 328 images left
# Already existing file TCGA-43-7657-01Z-00-DX1_{item} - 327 images left
# Already existing file TCGA-43-7658-01Z-00-DX1_{item} - 326 images left
# Already existing file TCGA-43-8115-01Z-00-DX1_{item} - 325 images left
# Already existing file TCGA-43-A474-01Z-00-DX1_{item} - 324 images left
# Already existing file TCGA-43-A475-01Z-00-DX1_{item} - 323 images left
# Already existing file TCGA-43-A56U-01Z-00-DX1_{item} - 322 images left
# Already existing file TCGA-43-A56V-01Z-00-DX1_{item} - 321 images left
# Already existing file TCGA-46-3765-01Z-00-DX1_{item} - 320 images left
# Already existing file TCGA-46-3766-01Z-00-DX1_{item} - 319 images left
# Already existing file TCGA-46-3767-01Z-00-DX1_{item} - 318 images left
# Already existing file TCGA-46-3768-01Z-00-DX1_{item} - 317 images left
# Already existing file TCGA-46-3769-01Z-00-DX1_{item} - 316 images left
# Already existing file TCGA-46-6025-01Z-00-DX1_{item} - 315 images left
# Already existing file TCGA-46-6026-01Z-00-DX1_{item} - 314 images left
# Already existing file TCGA-51-4079-01Z-00-DX1_{item} - 313 images left
# Already existing file TCGA-51-4080-01Z-00-DX1_{item} - 312 images left
# Already existing file TCGA-51-4081-01Z-00-DX1_{item} - 311 images left
# Already existing file TCGA-51-6867-01Z-00-DX1_{item} - 310 images left
# Already existing file TCGA-52-7622-01Z-00-DX1_{item} - 309 images left
# Already existing file TCGA-52-7809-01Z-00-DX1_{item} - 308 images left
# Already existing file TCGA-52-7810-01Z-00-DX1_{item} - 307 images left
# Already existing file TCGA-52-7811-01Z-00-DX1_{item} - 306 images left
# Already existing file TCGA-52-7812-01Z-00-DX1_{item} - 305 images left
# Already existing file TCGA-56-1622-01Z-00-DX1_{item} - 304 images left
# Already existing file TCGA-56-5897-01Z-00-DX1_{item} - 303 images left
# Already existing file TCGA-56-5898-01Z-00-DX1_{item} - 302 images left
# Already existing file TCGA-56-6545-01Z-00-DX1_{item} - 301 images left
# Already existing file TCGA-56-7221-01Z-00-DX1_{item} - 300 images left
# Already existing file TCGA-56-7222-01Z-00-DX1_{item} - 299 images left
# Already existing file TCGA-56-7223-01Z-00-DX1_{item} - 298 images left
# Already existing file TCGA-56-7579-01Z-00-DX1_{item} - 297 images left
# Already existing file TCGA-56-7580-01Z-00-DX1_{item} - 296 images left
# Already existing file TCGA-56-7582-01Z-00-DX1_{item} - 295 images left
# Already existing file TCGA-56-7730-01Z-00-DX1_{item} - 294 images left
# Already existing file TCGA-56-7731-01Z-00-DX1_{item} - 293 images left
# Already existing file TCGA-56-7822-01Z-00-DX1_{item} - 292 images left
# Already existing file TCGA-56-7823-01Z-00-DX1_{item} - 291 images left
# Already existing file TCGA-56-8082-01Z-00-DX1_{item} - 290 images left
# Already existing file TCGA-56-8083-01Z-00-DX1_{item} - 289 images left
# Already existing file TCGA-56-8201-01Z-00-DX1_{item} - 288 images left
# Already existing file TCGA-56-8304-01Z-00-DX1_{item} - 287 images left
# Already existing file TCGA-56-8305-01Z-00-DX1_{item} - 286 images left
# Already existing file TCGA-56-8307-01Z-00-DX1_{item} - 285 images left
# Already existing file TCGA-56-8308-01Z-00-DX1_{item} - 284 images left
# Already existing file TCGA-56-8309-01Z-00-DX1_{item} - 283 images left
# Already existing file TCGA-56-8503-01Z-00-DX1_{item} - 282 images left
# Already existing file TCGA-56-8504-01Z-00-DX1_{item} - 281 images left
# Already existing file TCGA-56-8622-01Z-00-DX1_{item} - 280 images left
# Already existing file TCGA-56-8623-01Z-00-DX1_{item} - 279 images left
# Already existing file TCGA-56-8624-01Z-00-DX1_{item} - 278 images left
# Already existing file TCGA-56-8625-01Z-00-DX1_{item} - 277 images left
# Already existing file TCGA-56-8626-01Z-00-DX1_{item} - 276 images left
# Already existing file TCGA-56-8628-01Z-00-DX1_{item} - 275 images left
# Already existing file TCGA-56-8629-01Z-00-DX1_{item} - 274 images left
# Already existing file TCGA-56-A49D-01Z-00-DX1_{item} - 273 images left
# Already existing file TCGA-56-A4BW-01Z-00-DX1_{item} - 272 images left
# Already existing file TCGA-56-A4BX-01Z-00-DX1_{item} - 271 images left
# Already existing file TCGA-56-A4BY-01Z-00-DX1_{item} - 270 images left
# Already existing file TCGA-56-A4ZJ-01Z-00-DX1_{item} - 269 images left
# Already existing file TCGA-56-A4ZK-01Z-00-DX1_{item} - 268 images left
# Already existing file TCGA-56-A5DR-01Z-00-DX1_{item} - 267 images left
# Already existing file TCGA-56-A5DS-01Z-00-DX1_{item} - 266 images left
# Already existing file TCGA-56-A62T-01Z-00-DX1_{item} - 265 images left
# Already existing file TCGA-58-A46J-01Z-00-DX1_{item} - 264 images left
# Already existing file TCGA-58-A46K-01Z-00-DX1_{item} - 263 images left
# Already existing file TCGA-58-A46L-01Z-00-DX1_{item} - 262 images left
# Already existing file TCGA-58-A46M-01Z-00-DX1_{item} - 261 images left
# Already existing file TCGA-58-A46N-01Z-00-DX1_{item} - 260 images left
# Already existing file TCGA-60-2695-01Z-00-DX1_{item} - 259 images left
# Already existing file TCGA-60-2696-01Z-00-DX1_{item} - 258 images left
# Already existing file TCGA-60-2697-01Z-00-DX1_{item} - 257 images left
# Already existing file TCGA-60-2698-01Z-00-DX1_{item} - 256 images left
# Already existing file TCGA-60-2703-01Z-00-DX1_{item} - 255 images left
# Already existing file TCGA-60-2704-01Z-00-DX1_{item} - 254 images left
# Already existing file TCGA-60-2706-01Z-00-DX1_{item} - 253 images left
# Already existing file TCGA-60-2707-01Z-00-DX1_{item} - 252 images left
# Already existing file TCGA-60-2708-01Z-00-DX1_{item} - 251 images left
# Already existing file TCGA-60-2709-01Z-00-DX1_{item} - 250 images left
# Already existing file TCGA-60-2710-01Z-00-DX1_{item} - 249 images left
# Already existing file TCGA-60-2711-01Z-00-DX1_{item} - 248 images left
# Already existing file TCGA-60-2712-01Z-00-DX1_{item} - 247 images left
# Already existing file TCGA-60-2713-01Z-00-DX1_{item} - 246 images left
# Already existing file TCGA-60-2714-01Z-00-DX1_{item} - 245 images left
# Already existing file TCGA-60-2715-01Z-00-DX1_{item} - 244 images left
# Already existing file TCGA-60-2716-01Z-00-DX1_{item} - 243 images left
# Already existing file TCGA-60-2719-01Z-00-DX1_{item} - 242 images left
# Already existing file TCGA-60-2720-01Z-00-DX1_{item} - 241 images left
# Already existing file TCGA-60-2721-01Z-00-DX1_{item} - 240 images left
# Already existing file TCGA-60-2722-01Z-00-DX1_{item} - 239 images left
# Already existing file TCGA-60-2723-01Z-00-DX1_{item} - 238 images left
# Already existing file TCGA-60-2724-01Z-00-DX1_{item} - 237 images left
# Already existing file TCGA-60-2725-01Z-00-DX1_{item} - 236 images left
# Already existing file TCGA-60-2726-01Z-00-DX1_{item} - 235 images left
# Already existing file TCGA-63-6202-01Z-00-DX1_{item} - 234 images left
# Already existing file TCGA-63-7020-01Z-00-DX1_{item} - 233 images left
# Already existing file TCGA-63-7021-01Z-00-DX1_{item} - 232 images left
# Already existing file TCGA-63-7022-01Z-00-DX1_{item} - 231 images left
# Already existing file TCGA-63-7023-01Z-00-DX1_{item} - 230 images left
# Already existing file TCGA-63-A5M9-01Z-00-DX1_{item} - 229 images left
# Already existing file TCGA-63-A5MB-01Z-00-DX1_{item} - 228 images left
# Already existing file TCGA-63-A5MG-01Z-00-DX1_{item} - 227 images left
# Already existing file TCGA-63-A5MH-01Z-00-DX1_{item} - 226 images left
# Already existing file TCGA-63-A5MI-01Z-00-DX1_{item} - 225 images left
# Already existing file TCGA-63-A5MJ-01Z-00-DX1_{item} - 224 images left
# Already existing file TCGA-63-A5ML-01Z-00-DX1_{item} - 223 images left
# Already existing file TCGA-63-A5MM-01Z-00-DX1_{item} - 222 images left
# Already existing file TCGA-63-A5MN-01Z-00-DX1_{item} - 221 images left
# Already existing file TCGA-63-A5MP-01Z-00-DX1_{item} - 220 images left
# Already existing file TCGA-63-A5MR-01Z-00-DX1_{item} - 219 images left
# Already existing file TCGA-63-A5MS-01Z-00-DX1_{item} - 218 images left
# Already existing file TCGA-63-A5MT-01Z-00-DX1_{item} - 217 images left
# Already existing file TCGA-63-A5MU-01Z-00-DX1_{item} - 216 images left
# Already existing file TCGA-63-A5MV-01Z-00-DX1_{item} - 215 images left
# Already existing file TCGA-63-A5MW-01Z-00-DX1_{item} - 214 images left
# Already existing file TCGA-63-A5MY-01Z-00-DX1_{item} - 213 images left
# Already existing file TCGA-66-2727-01Z-00-DX1_{item} - 212 images left
# Already existing file TCGA-66-2734-01Z-00-DX1_{item} - 211 images left
# Already existing file TCGA-66-2737-01Z-00-DX1_{item} - 210 images left
# Already existing file TCGA-66-2742-01Z-00-DX1_{item} - 209 images left
# Already existing file TCGA-66-2744-01Z-00-DX1_{item} - 208 images left
# Already existing file TCGA-66-2753-01Z-00-DX1_{item} - 207 images left
# Already existing file TCGA-66-2754-01Z-00-DX1_{item} - 206 images left
# Already existing file TCGA-66-2755-01Z-00-DX1_{item} - 205 images left
# Already existing file TCGA-66-2756-01Z-00-DX1_{item} - 204 images left
# Already existing file TCGA-66-2757-01Z-00-DX1_{item} - 203 images left
# Already existing file TCGA-66-2758-01Z-00-DX1_{item} - 202 images left
# Already existing file TCGA-66-2759-01Z-00-DX1_{item} - 201 images left
# Already existing file TCGA-66-2763-01Z-00-DX1_{item} - 200 images left
# Already existing file TCGA-66-2765-01Z-00-DX1_{item} - 199 images left
# Already existing file TCGA-66-2766-01Z-00-DX1_{item} - 198 images left
# Already existing file TCGA-66-2767-01Z-00-DX1_{item} - 197 images left
# Already existing file TCGA-66-2768-01Z-00-DX1_{item} - 196 images left
# Already existing file TCGA-66-2769-01Z-00-DX1_{item} - 195 images left
# Already existing file TCGA-66-2770-01Z-00-DX1_{item} - 194 images left
# Already existing file TCGA-66-2770-01Z-00-DX2_{item} - 193 images left
# Already existing file TCGA-66-2771-01Z-00-DX1_{item} - 192 images left
# Already existing file TCGA-66-2773-01Z-00-DX1_{item} - 191 images left
# Already existing file TCGA-66-2777-01Z-00-DX1_{item} - 190 images left
# Already existing file TCGA-66-2778-01Z-00-DX1_{item} - 189 images left
# Already existing file TCGA-66-2780-01Z-00-DX1_{item} - 188 images left
# Already existing file TCGA-66-2781-01Z-00-DX1_{item} - 187 images left
# Already existing file TCGA-66-2783-01Z-00-DX1_{item} - 186 images left
# Already existing file TCGA-66-2785-01Z-00-DX1_{item} - 185 images left
# Already existing file TCGA-66-2786-01Z-00-DX1_{item} - 184 images left
# Already existing file TCGA-66-2787-01Z-00-DX1_{item} - 183 images left
# Already existing file TCGA-66-2788-01Z-00-DX1_{item} - 182 images left
# Already existing file TCGA-66-2789-01Z-00-DX1_{item} - 181 images left
# Already existing file TCGA-66-2790-01Z-00-DX1_{item} - 180 images left
# Already existing file TCGA-66-2791-01Z-00-DX1_{item} - 179 images left
# Already existing file TCGA-66-2792-01Z-00-DX1_{item} - 178 images left
# Already existing file TCGA-66-2793-01Z-00-DX1_{item} - 177 images left
# Already existing file TCGA-66-2794-01Z-00-DX1_{item} - 176 images left
# Already existing file TCGA-66-2795-01Z-00-DX1_{item} - 175 images left
# Already existing file TCGA-66-2800-01Z-00-DX1_{item} - 174 images left
# Already existing file TCGA-68-7755-01Z-00-DX1_{item} - 173 images left
# Already existing file TCGA-68-7756-01Z-00-DX1_{item} - 172 images left
# Already existing file TCGA-68-7757-01Z-00-DX1_{item} - 171 images left
# Already existing file TCGA-68-8250-01Z-00-DX1_{item} - 170 images left
# Already existing file TCGA-68-8251-01Z-00-DX1_{item} - 169 images left
# Already existing file TCGA-68-A59I-01Z-00-DX1_{item} - 168 images left
# Already existing file TCGA-68-A59J-01Z-00-DX1_{item} - 167 images left
# Already existing file TCGA-70-6722-01Z-00-DX1_{item} - 166 images left
# Already existing file TCGA-70-6723-01Z-00-DX1_{item} - 165 images left
# Already existing file TCGA-77-6842-01Z-00-DX1_{item} - 164 images left
# Already existing file TCGA-77-6843-01Z-00-DX1_{item} - 163 images left
# Already existing file TCGA-77-6844-01Z-00-DX1_{item} - 162 images left
# Already existing file TCGA-77-6845-01Z-00-DX1_{item} - 161 images left
# Already existing file TCGA-77-7138-01Z-00-DX1_{item} - 160 images left
# Already existing file TCGA-77-7139-01Z-00-DX1_{item} - 159 images left
# Already existing file TCGA-77-7140-01Z-00-DX1_{item} - 158 images left
# Already existing file TCGA-77-7141-01Z-00-DX1_{item} - 157 images left
# Already existing file TCGA-77-7142-01Z-00-DX1_{item} - 156 images left
# Already existing file TCGA-77-7335-01Z-00-DX1_{item} - 155 images left
# Already existing file TCGA-77-7337-01Z-00-DX1_{item} - 154 images left
# Already existing file TCGA-77-7338-01Z-00-DX1_{item} - 153 images left
# Already existing file TCGA-77-7463-01Z-00-DX1_{item} - 152 images left
# Already existing file TCGA-77-7465-01Z-00-DX1_{item} - 151 images left
# Already existing file TCGA-77-8007-01Z-00-DX1_{item} - 150 images left
# Already existing file TCGA-77-8008-01Z-00-DX1_{item} - 149 images left
# Already existing file TCGA-77-8009-01Z-00-DX1_{item} - 148 images left
# Already existing file TCGA-77-8128-01Z-00-DX1_{item} - 147 images left
# Already existing file TCGA-77-8130-01Z-00-DX1_{item} - 146 images left
# Already existing file TCGA-77-8131-01Z-00-DX1_{item} - 145 images left
# Already existing file TCGA-77-8133-01Z-00-DX1_{item} - 144 images left
# Already existing file TCGA-77-8136-01Z-00-DX1_{item} - 143 images left
# Already existing file TCGA-77-8138-01Z-00-DX1_{item} - 142 images left
# Already existing file TCGA-77-8139-01Z-00-DX1_{item} - 141 images left
# Already existing file TCGA-77-8140-01Z-00-DX1_{item} - 140 images left
# Already existing file TCGA-77-8143-01Z-00-DX1_{item} - 139 images left
# Already existing file TCGA-77-8144-01Z-00-DX1_{item} - 138 images left
# Already existing file TCGA-77-8145-01Z-00-DX1_{item} - 137 images left
# Already existing file TCGA-77-8146-01Z-00-DX1_{item} - 136 images left
# Already existing file TCGA-77-8148-01Z-00-DX1_{item} - 135 images left
# Already existing file TCGA-77-8150-01Z-00-DX1_{item} - 134 images left
# Already existing file TCGA-77-8153-01Z-00-DX1_{item} - 133 images left
# Already existing file TCGA-77-8154-01Z-00-DX1_{item} - 132 images left
# Already existing file TCGA-77-8156-01Z-00-DX1_{item} - 131 images left
# Already existing file TCGA-77-A5FZ-01Z-00-DX1_{item} - 130 images left
# Already existing file TCGA-77-A5G1-01Z-00-DX1_{item} - 129 images left
# Already existing file TCGA-77-A5G3-01Z-00-DX1_{item} - 128 images left
# Already existing file TCGA-77-A5G6-01Z-00-DX1_{item} - 127 images left
# Already existing file TCGA-77-A5G7-01Z-00-DX1_{item} - 126 images left
# Already existing file TCGA-77-A5G8-01Z-00-DX1_{item} - 125 images left
# Already existing file TCGA-77-A5GA-01Z-00-DX1_{item} - 124 images left
# Already existing file TCGA-77-A5GB-01Z-00-DX1_{item} - 123 images left
# Already existing file TCGA-77-A5GF-01Z-00-DX1_{item} - 122 images left
# Already existing file TCGA-77-A5GH-01Z-00-DX1_{item} - 121 images left
# Already existing file TCGA-85-6175-01Z-00-DX1_{item} - 120 images left
# Already existing file TCGA-85-6560-01Z-00-DX1_{item} - 119 images left
# Already existing file TCGA-85-6561-01Z-00-DX1_{item} - 118 images left
# Already existing file TCGA-85-6798-01Z-00-DX1_{item} - 117 images left
# Already existing file TCGA-85-7696-01Z-00-DX1_{item} - 116 images left
# Already existing file TCGA-85-7697-01Z-00-DX1_{item} - 115 images left
# Already existing file TCGA-85-7698-01Z-00-DX1_{item} - 114 images left
# Already existing file TCGA-85-7699-01Z-00-DX1_{item} - 113 images left
# Already existing file TCGA-85-7710-01Z-00-DX1_{item} - 112 images left
# Already existing file TCGA-85-7843-01Z-00-DX1_{item} - 111 images left
# Already existing file TCGA-85-7844-01Z-00-DX1_{item} - 110 images left
# Already existing file TCGA-85-7950-01Z-00-DX1_{item} - 109 images left
# Already existing file TCGA-85-8048-01Z-00-DX1_{item} - 108 images left
# Already existing file TCGA-85-8049-01Z-00-DX1_{item} - 107 images left
# Already existing file TCGA-85-8052-01Z-00-DX1_{item} - 106 images left
# Already existing file TCGA-85-8070-01Z-00-DX1_{item} - 105 images left
# Already existing file TCGA-85-8071-01Z-00-DX1_{item} - 104 images left
# Already existing file TCGA-85-8072-01Z-00-DX1_{item} - 103 images left
# Already existing file TCGA-85-8276-01Z-00-DX1_{item} - 102 images left
# Already existing file TCGA-85-8277-01Z-00-DX1_{item} - 101 images left
# Already existing file TCGA-85-8287-01Z-00-DX1_{item} - 100 images left
# Already existing file TCGA-85-8288-01Z-00-DX1_{item} - 99 images left
# Already existing file TCGA-85-8350-01Z-00-DX1_{item} - 98 images left
# Already existing file TCGA-85-8351-01Z-00-DX1_{item} - 97 images left
# Already existing file TCGA-85-8352-01Z-00-DX1_{item} - 96 images left
# Already existing file TCGA-85-8353-01Z-00-DX1_{item} - 95 images left
# Already existing file TCGA-85-8354-01Z-00-DX1_{item} - 94 images left
# Already existing file TCGA-85-8355-01Z-00-DX1_{item} - 93 images left
# Already existing file TCGA-85-8479-01Z-00-DX1_{item} - 92 images left
# Already existing file TCGA-85-8481-01Z-00-DX1_{item} - 91 images left
# Already existing file TCGA-85-8580-01Z-00-DX1_{item} - 90 images left
# Already existing file TCGA-85-8582-01Z-00-DX1_{item} - 89 images left
# Already existing file TCGA-85-8584-01Z-00-DX1_{item} - 88 images left
# Already existing file TCGA-85-8664-01Z-00-DX1_{item} - 87 images left
# Already existing file TCGA-85-8666-01Z-00-DX1_{item} - 86 images left
# Already existing file TCGA-85-A4CL-01Z-00-DX1_{item} - 85 images left
# Already existing file TCGA-85-A4CN-01Z-00-DX1_{item} - 84 images left
# Already existing file TCGA-85-A4JB-01Z-00-DX1_{item} - 83 images left
# Already existing file TCGA-85-A4JC-01Z-00-DX1_{item} - 82 images left
# Already existing file TCGA-85-A4PA-01Z-00-DX1_{item} - 81 images left
# Already existing file TCGA-85-A4QQ-01Z-00-DX1_{item} - 80 images left
# Already existing file TCGA-85-A4QR-01Z-00-DX1_{item} - 79 images left
# Already existing file TCGA-85-A50M-01Z-00-DX1_{item} - 78 images left
# Already existing file TCGA-85-A50Z-01Z-00-DX1_{item} - 77 images left
# Already existing file TCGA-85-A510-01Z-00-DX1_{item} - 76 images left
# Already existing file TCGA-85-A511-01Z-00-DX1_{item} - 75 images left
# Already existing file TCGA-85-A512-01Z-00-DX1_{item} - 74 images left
# Already existing file TCGA-85-A513-01Z-00-DX1_{item} - 73 images left
# Already existing file TCGA-85-A53L-01Z-00-DX1_{item} - 72 images left
# Already existing file TCGA-85-A5B5-01Z-00-DX1_{item} - 71 images left
# Already existing file TCGA-90-7964-01Z-00-DX1_{item} - 70 images left
# Already existing file TCGA-90-A4ED-01Z-00-DX1_{item} - 69 images left
# Already existing file TCGA-90-A4EE-01Z-00-DX1_{item} - 68 images left
# Already existing file TCGA-90-A59Q-01Z-00-DX1_{item} - 67 images left
# Already existing file TCGA-92-7340-01Z-00-DX1_{item} - 66 images left
# Already existing file TCGA-92-7341-01Z-00-DX1_{item} - 65 images left
# Already existing file TCGA-92-8063-01Z-00-DX1_{item} - 64 images left
# Already existing file TCGA-92-8064-01Z-00-DX1_{item} - 63 images left
# Already existing file TCGA-92-8065-01Z-00-DX1_{item} - 62 images left
# Already existing file TCGA-94-7033-01Z-00-DX1_{item} - 61 images left
# Already existing file TCGA-94-7557-01Z-00-DX1_{item} - 60 images left
# Already existing file TCGA-94-7943-01Z-00-DX1_{item} - 59 images left
# Already existing file TCGA-94-8035-01Z-00-DX1_{item} - 58 images left
# Already existing file TCGA-94-8490-01Z-00-DX1_{item} - 57 images left
# Already existing file TCGA-94-8491-01Z-00-DX1_{item} - 56 images left
# Already existing file TCGA-94-A4VJ-01Z-00-DX1_{item} - 55 images left
# Already existing file TCGA-94-A5I4-01Z-00-DX1_{item} - 54 images left
# Already existing file TCGA-94-A5I6-01Z-00-DX1_{item} - 53 images left
# Already existing file TCGA-96-7544-01Z-00-DX1_{item} - 52 images left
# Already existing file TCGA-96-7545-01Z-00-DX1_{item} - 51 images left
# Already existing file TCGA-96-8169-01Z-00-DX1_{item} - 50 images left
# Already existing file TCGA-96-8170-01Z-00-DX1_{item} - 49 images left
# Already existing file TCGA-96-A4JK-01Z-00-DX1_{item} - 48 images left
# Already existing file TCGA-96-A4JL-01Z-00-DX1_{item} - 47 images left
# Already existing file TCGA-98-7454-01Z-00-DX1_{item} - 46 images left
# Already existing file TCGA-98-8020-01Z-00-DX1_{item} - 45 images left
# Already existing file TCGA-98-8021-01Z-00-DX1_{item} - 44 images left
# Already existing file TCGA-98-8022-01Z-00-DX1_{item} - 43 images left
# Already existing file TCGA-98-8023-01Z-00-DX1_{item} - 42 images left
# Already existing file TCGA-98-A538-01Z-00-DX1_{item} - 41 images left
# Already existing file TCGA-98-A539-01Z-00-DX1_{item} - 40 images left
# Already existing file TCGA-98-A53A-01Z-00-DX1_{item} - 39 images left
# Already existing file TCGA-98-A53B-01Z-00-DX1_{item} - 38 images left
# Already existing file TCGA-98-A53C-01Z-00-DX1_{item} - 37 images left
# Already existing file TCGA-98-A53D-01Z-00-DX1_{item} - 36 images left
# Already existing file TCGA-98-A53H-01Z-00-DX1_{item} - 35 images left
# Already existing file TCGA-98-A53I-01Z-00-DX1_{item} - 34 images left
# Already existing file TCGA-98-A53J-01Z-00-DX1_{item} - 33 images left
# Already existing file TCGA-J1-A4AH-01Z-00-DX1_{item} - 32 images left
# Already existing file TCGA-L3-A4E7-01Z-00-DX1_{item} - 31 images left
# Already existing file TCGA-L3-A524-01Z-00-DX1_{item} - 30 images left
# Already existing file TCGA-LA-A446-01Z-00-DX1_{item} - 29 images left
# Already existing file TCGA-LA-A7SW-01Z-00-DX1_{item} - 28 images left
# Already existing file TCGA-MF-A522-01Z-00-DX1_{item} - 27 images left
# Already existing file TCGA-NC-A5HD-01Z-00-DX1_{item} - 26 images left
# Already existing file TCGA-NC-A5HE-01Z-00-DX1_{item} - 25 images left
# Already existing file TCGA-NC-A5HF-01Z-00-DX1_{item} - 24 images left
# Already existing file TCGA-NC-A5HG-01Z-00-DX1_{item} - 23 images left
# Already existing file TCGA-NC-A5HH-01Z-00-DX1_{item} - 22 images left
# Already existing file TCGA-NC-A5HI-01Z-00-DX1_{item} - 21 images left
# Already existing file TCGA-NC-A5HJ-01Z-00-DX1_{item} - 20 images left
# Already existing file TCGA-NC-A5HK-01Z-00-DX1_{item} - 19 images left
# Already existing file TCGA-NC-A5HL-01Z-00-DX1_{item} - 18 images left
# Already existing file TCGA-NC-A5HM-01Z-00-DX1_{item} - 17 images left
# Already existing file TCGA-NC-A5HN-01Z-00-DX1_{item} - 16 images left
# Already existing file TCGA-NC-A5HO-01Z-00-DX1_{item} - 15 images left
# Already existing file TCGA-NC-A5HP-01Z-00-DX1_{item} - 14 images left
# Already existing file TCGA-NC-A5HQ-01Z-00-DX1_{item} - 13 images left
# Already existing file TCGA-NC-A5HR-01Z-00-DX1_{item} - 12 images left
# Already existing file TCGA-NC-A5HT-01Z-00-DX1_{item} - 11 images left
# Already existing file TCGA-NK-A5CR-01Z-00-DX1_{item} - 10 images left
# Already existing file TCGA-NK-A5CT-01Z-00-DX1_{item} - 9 images left
# Already existing file TCGA-NK-A5CX-01Z-00-DX1_{item} - 8 images left
# Already existing file TCGA-NK-A5D1-01Z-00-DX1_{item} - 7 images left
# Already existing file TCGA-NK-A7XE-01Z-00-DX1_{item} - 6 images left
# Already existing file TCGA-O2-A52N-01Z-00-DX1_{item} - 5 images left
# Already existing file TCGA-O2-A52S-01Z-00-DX1_{item} - 4 images left
# Already existing file TCGA-O2-A52V-01Z-00-DX1_{item} - 3 images left
# Already existing file TCGA-O2-A52W-01Z-00-DX1_{item} - 2 images left
# Already existing file TCGA-O2-A5IB-01Z-00-DX1_{item} - 1 images left
# Already existing file TCGA-XC-AA0X-01Z-00-DX1_{item} - 0 images left
# Finish Processing All images!

# %% [markdown]
# ## 3. Train CNN on compressed images ##
#
# Once we have compressed the WSIs, we can proceed with the CNN classifier. In this example, we will train a classifier targeting the binary label `HGP_SL` found in the CSV file. We will be training 4 models using cross-validation: in each fold, we will use 2 data partitions for training, 1 for validation and 1 for testing. At the end of model training, we perform inference on the test set, compute metrics, and run GradCAM on the images.

# %%
from model_training import train_wsi_classifier, eval_model, compute_metrics
from utils import check_file_exists

def train_model(featurized_dir, csv_path, fold_n, output_dir, cache_dir, batch_size=16, epochs=32,
                images_dir=None, vectorized_dir=None, lr=1e-2, patience=4, delete_folder=False,
                occlusion_augmentation=False, elastic_augmentation=False, shuffle_augmentation=None):
    """
    Trains a CNN using compressed whole-slide images.

    :param featurized_dir: folder containing the compressed (featurized) images.
    :param csv_path: list of slides with labels.
    :param fold_n: fold determining which data partitions to use for training, validation and testing.
    :param output_dir: destination folder to store results.
    :param cache_dir: folder to store compressed images temporarily for fast access.
    :param batch_size: number of samples to train with in one-go.
    :return: nothing.
    """
    
    # Delete folder and subfolders if exists
    if delete_folder: 
        if exists(result_dir):  shutil.rmtree(result_dir)
            
    # Train CNN
    train_wsi_classifier(
        data_dir=featurized_dir,
        csv_path=csv_path,
        partitions=None,
        crop_size=400,
        output_dir=output_dir,
        output_units=2,
        cache_dir=cache_dir,
        n_epochs=epochs,
        batch_size=batch_size,
        lr=lr,
        code_size=128,
        workers=1,
        train_step_multiplier=1,
        val_step_multiplier=0.5,
        keep_data_training=1,
        keep_data_validation=1,
        patience=patience,
        occlusion_augmentation=occlusion_augmentation,
        elastic_augmentation=elastic_augmentation,
        shuffle_augmentation=shuffle_augmentation
    )  

    # Evaluate CNN 
    
    # Get compressed wsi directories with csv test file
    data_config = featurized_dir
    data_config['csv_path'] = csv_path['csv_test']
    
    eval_model(
        model_path=join(output_dir, 'checkpoint.h5'),
        data_config=data_config,
        crop_size=400,
        output_path=join(output_dir, 'eval', 'preds.csv'),
        cache_dir=None,
        batch_size=batch_size,
        keep_data=1
    )

    # Metrics
    try:
        compute_metrics(
            input_path=join(output_dir, 'eval', 'preds.csv'),
            output_dir=join(output_dir, 'eval')
        )
    except Exception as e:
        print('Failed to compute metrics. Exception: {e}'.format(e=e), flush=True)

#     # Apply GradCAM analysis to CNN
#     gradcam_on_dataset(
#         featurized_dir=featurized_dir,
#         csv_path=csv_path,
#         model_path=join(output_dir, 'checkpoint.h5'),
#         partitions=folds[fold_n]['test'],
#         layer_name='separable_conv2d_1',
#         output_unit=1,
#         custom_objects=None,
#         cache_dir=cache_dir,
#         images_dir=images_dir,
#         vectorized_dir=vectorized_dir
#     )

# %%
# Train CNN

#selected_fold = 0

featurized_dir = {'data_dir_luad': featurized_luad_dir, 'data_dir_lusc': featurized_lusc_dir}
csv_path = {'csv_train': csv_train, 'csv_val': csv_val, 'csv_test': csv_test}

train_model(
    featurized_dir=featurized_dir,
    csv_path=csv_path,
    fold_n=0, 
    output_dir=result_dir,
    cache_dir=None,
    batch_size =4,
    epochs=2,
    delete_folder=True,
    occlusion_augmentation=False,
    lr=1e-2,
    patience=4,
    elastic_augmentation=False,
    images_dir=None,  # required for GradCAM
    vectorized_dir=None,  # required for GradCAM
    shuffle_augmentation=None
)
# Out:
# Loading training set ...
# FeaturizedWsiGenerator data config: {'data_dir_luad': '/mnt/netcache/pathology/projects/pathology-weakly-supervised-lung-cancer-growth-pattern-prediction/results/tcga_luad/featurized/no_augmentations', 'data_dir_lusc': '/mnt/netcache/pathology/projects/pathology-weakly-supervised-lung-cancer-growth-pattern-prediction/results/tcga_lusc/featurized/no_augmentations', 'csv_path': '/mnt/netcache/pathology/archives/lung/train_slide_list_tcga.csv'}
# FeaturizedWsiGenerator using 580 samples and 145 batches, distributed in 306 positive and 274 negative samples.
# Loading validation set ...
# FeaturizedWsiSequence data config: {'data_dir_luad': '/mnt/netcache/pathology/projects/pathology-weakly-supervised-lung-cancer-growth-pattern-prediction/results/tcga_luad/featurized/no_augmentations', 'data_dir_lusc': '/mnt/netcache/pathology/projects/pathology-weakly-supervised-lung-cancer-growth-pattern-prediction/results/tcga_lusc/featurized/no_augmentations', 'csv_path': '/mnt/netcache/pathology/archives/lung/validation_slide_list_tcga.csv'}
# FeaturizedWsiSequence using 249 samples and 64 batches, distributed in 128 positive and 121 negative samples.
# Building model ...
# Training model ...
# Training model in directory: /mnt/netcache/pathology/projects/pathology-weakly-supervised-lung-cancer-growth-pattern-prediction/results/baseline_model_full_data with content 0
# Training model from scratch False False...
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 400, 400, 128)     0
# _________________________________________________________________
# separable_conv2d_1 (Separabl (None, 199, 199, 128)     17664
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 199, 199, 128)     512
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 199, 199, 128)     0
# _________________________________________________________________
# spatial_dropout2d_1 (Spatial (None, 199, 199, 128)     0
# _________________________________________________________________
# separable_conv2d_2 (Separabl (None, 99, 99, 128)       17664
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 99, 99, 128)       512
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 99, 99, 128)       0
# _________________________________________________________________
# spatial_dropout2d_2 (Spatial (None, 99, 99, 128)       0
# _________________________________________________________________
# separable_conv2d_3 (Separabl (None, 49, 49, 128)       17664
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 49, 49, 128)       512
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 49, 49, 128)       0
# _________________________________________________________________
# spatial_dropout2d_3 (Spatial (None, 49, 49, 128)       0
# _________________________________________________________________
# separable_conv2d_4 (Separabl (None, 24, 24, 128)       17664
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 24, 24, 128)       512
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 24, 24, 128)       0
# _________________________________________________________________
# spatial_dropout2d_4 (Spatial (None, 24, 24, 128)       0
# _________________________________________________________________
# separable_conv2d_5 (Separabl (None, 11, 11, 128)       17664
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 11, 11, 128)       512
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 11, 11, 128)       0
# _________________________________________________________________
# spatial_dropout2d_5 (Spatial (None, 11, 11, 128)       0
# _________________________________________________________________
# separable_conv2d_6 (Separabl (None, 5, 5, 128)         17664
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 5, 5, 128)         512
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 5, 5, 128)         0
# _________________________________________________________________
# spatial_dropout2d_6 (Spatial (None, 5, 5, 128)         0
# _________________________________________________________________
# separable_conv2d_7 (Separabl (None, 3, 3, 128)         17664
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 3, 3, 128)         512
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 3, 3, 128)         0
# _________________________________________________________________
# spatial_dropout2d_7 (Spatial (None, 3, 3, 128)         0
# _________________________________________________________________
# separable_conv2d_8 (Separabl (None, 1, 1, 128)         17664
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 1, 1, 128)         512
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 1, 1, 128)         0
# _________________________________________________________________
# spatial_dropout2d_8 (Spatial (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 128)               512
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 258
# _________________________________________________________________
# activation_1 (Activation)    (None, 2)                 0
# =================================================================
# Total params: 162,690
# Trainable params: 160,386
# Non-trainable params: 2,304
# _________________________________________________________________
# Epoch 1/2
#  15/145 [==>...........................] - ETA: 20:23 - loss: 1.1900 - categorical_accuracy: 0.5500

# %% [markdown]
# ## Aplying GradCam
#
# Here we get the folder separetely

# %%
print('GradCam will be apply to this dataset!')
csv_path_luad_feat = join(data_dir, 'slide_list_featurized_luad.csv')
data_to_csv(featurized_luad_dir, csv_path_luad_feat)
pd.read_csv(csv_path_luad_feat)

# %%
# for layer in model.layers:
#     print(layer.name)
# Apply GradCAM analysis to CNN on LUAD data

# Apply GradCam on layer 1
gradcam_on_dataset(
    data_dir=[featurized_luad_dir, featurized_lusc_dir],
    csv_path=csv_path_luad_feat,
    model_path=join(result_dir, 'checkpoint.h5'),
    partitions=0,
    layer_number=1,
    custom_objects=None,
    cache_dir=cache_dir,
    images_dir=dir_luad_wsi,
    vectorized_dir=vectorized_luad_dir,
    output_dir=gradcam_dir,
    predict_two_output = True
)

# %%
def plot_gradcam(gradcam_images):
    # %matplotlib inline
    rows = 3; columns = 5;
    fig, axs = plt.subplots(rows,columns,figsize=(20,8))
    axs = axs.ravel()
    n_images = rows * columns

    for idx in range(n_images):
        img = plt.imread(gradcam_images[idx])
        if idx == 0: print(f'Images shape: {img.shape}')
        axs[idx].imshow(img)
        prefix = os.path.basename(gradcam_images[idx]).split('_')[0]
        subfix = os.path.basename(gradcam_images[idx]).split('_')[-1]
        axs[idx].set_title(prefix + '_' + subfix)
        axs[idx].set_xlabel(prefix + subfix)
        axs[idx].get_xaxis().set_visible(False)
        axs[idx].get_yaxis().set_visible(False)

# %%
# Get gradcam images
gradcam_images = sorted([os.path.join(gradcam_dir, f) for f in os.listdir(gradcam_dir) if f.endswith('.png')])

# Plot images
plot_gradcam(gradcam_images)
